# %% [markdown]
# # Executive Order Sentiment

# %%
import json
import os
from langchain_ollama import ChatOllama
from langchain.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from pydantic import BaseModel, Field
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas

# %% [markdown]
# ## Sentiment
#
# https://arxiv.org/pdf/2312.06281

# %%
def build_stats(result):
    return {
        'input_tokens': result['raw'].usage_metadata['input_tokens'],
        'output_tokens': result['raw'].usage_metadata['output_tokens']
    }

# %%
class EmotionScores(BaseModel):
    joy: int = Field(description="Joy conveyed on a scale of 1-10.")
    sadness: int = Field(description="sadness conveyed on a scale of 1-10.")
    fear: int = Field(description="fear conveyed on a scale of 1-10.")
    disgust: int = Field(description="disgust conveyed on a scale of 1-10.")
    surprise: int = Field(description="surprise conveyed on a scale of 1-10.")

class EmotionResponse(BaseModel):
    initial_scores: EmotionScores = Field(description="Initial emotion scores.")
    critique: str = Field(description="Critique of the initial scores.")
    revised_scores: EmotionScores = Field(description="Revised emotion scores.")

prompt = ChatPromptTemplate.from_template(
    '\n '.join([
        'Your task is to understand and score the emotions the president is conveying in the following executive order.',
        '- Does the president want the audience to feel joy, sadness, anger, fear, disgust, or surprise after reading the executive order? '
        '- For each emotion that should be conveyed, score the relative intensity on a scale of 1-10.',
        '- Critique your answer by thinking through it step by step.'
        '- Finally, give your revised scores.'
        '{text}',
    ])
)

def make_pipeline(model):
    return prompt | model.with_structured_output(EmotionResponse, include_raw=True)

# %%
gemini = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0,
    max_retries=3
)

# %%
source_dir = 'data/executive_orders/cleaned/'
target_dir = 'data/executive_orders/sentiment/'
log_path = 'data/executive_orders/sentiment_log.csv'

sentiment_pipeline = make_pipeline(gemini)

def process_eo(eo_path):
    stats = {
        'path': eo_path
    }

    start_time = time.time()
    try:
        with open(source_dir + eo_path) as source_file:
            eo = json.load(source_file)
            result = sentiment_pipeline.invoke({'text': '\n'.join(eo["content"])})
            stats = stats | build_stats(result)

        # write the cleaned eo to the target directory
        with open(target_dir + eo_path, 'w') as target_file:
            json.dump(result['parsed'].model_dump(), target_file, indent=4)
    except Exception as e:
        stats['error'] = str(e)

    duration = time.time() - start_time
    stats['duration'] = duration

    return stats

# %%
concurrency = 8

eo_paths = os.listdir(source_dir)
eo_paths.sort()

results = []
with ThreadPoolExecutor(max_workers=concurrency) as executor:
    futures = [
        executor.submit(process_eo, path) for path in eo_paths
    ]

    for future in as_completed(futures):
        result = future.result()
        print(result)
        results.append(result)

pandas.DataFrame(results).to_csv(log_path, index=False)
# Out:
# {'path': 'executive-order-10000-regulations-governing-additional-compensation-and-credit-granted.json', 'input_tokens': 4825, 'output_tokens': 73, 'duration': 1.4616789817810059}
# {'path': 'executive-order-10.json', 'input_tokens': 356, 'output_tokens': 84, 'duration': 1.4895906448364258}
# {'path': 'executive-order-1.json', 'input_tokens': 314, 'output_tokens': 102, 'duration': 1.5081360340118408}
# {'path': 'commission-appointing-commissioners-for-surveying-the-district-territory-for-the-permanent.json', 'input_tokens': 569, 'output_tokens': 94, 'duration': 1.5240669250488281}
# {'path': 'executive-order-1000-alamo-national-forest-new-mexico.json', 'input_tokens': 1183, 'output_tokens': 110, 'duration': 1.6396288871765137}
# {'path': 'executive-order-0.json', 'input_tokens': 314, 'output_tokens': 80, 'duration': 1.8411200046539307}
# {'path': 'executive-order-10001-prescribing-or-amending-portions-the-selective-service-regulations.json', 'input_tokens': 21358, 'output_tokens': 92, 'duration': 1.9496021270751953}
# {'path': 'executive-order-100.json', 'input_tokens': 580, 'output_tokens': 145, 'duration': 2.039428472518921}
# {'path': 'executive-order-10004-prescribing-procedures-for-the-administration-the-reciprocal-trade.json', 'input_tokens': 2802, 'output_tokens': 76, 'duration': 1.1040894985198975}
# {'path': 'executive-order-10005-establishing-the-presidents-advisory-commission-the-relation-federal.json', 'input_tokens': 714, 'output_tokens': 90, 'duration': 1.1820313930511475}
# {'path': 'executive-order-10006-preparation-presentation-filing-and-publicaton-executive-orders-and.json', 'input_tokens': 1253, 'output_tokens': 71, 'duration': 1.0758998394012451}
# {'path': 'executive-order-10002-exemption-lawrence-m-lawson-from-compulsory-retirement-for-age.json', 'input_tokens': 273, 'output_tokens': 92, 'duration': 1.2826759815216064}
# {'path': 'executive-order-10007-organization-the-reserve-units-the-armed-forces.json', 'input_tokens': 650, 'output_tokens': 97, 'duration': 1.3787882328033447}
# {'path': 'executive-order-10009-revoking-part-executive-orders-no-589-march-14-1907-and-no-1712.json', 'input_tokens': 769, 'output_tokens': 101, 'duration': 1.3913733959197998}
# {'path': 'executive-order-10008-amending-the-selective-service-regulations.json', 'input_tokens': 7163, 'output_tokens': 81, 'duration': 1.554844617843628}
# {'path': 'executive-order-10003-providing-for-the-investigation-and-report-displaced-persons-seeking.json', 'input_tokens': 483, 'output_tokens': 148, 'duration': 2.061821460723877}
# {'path': 'executive-order-10012-excluding-from-the-provisions-the-classification-act-1923-amended.json', 'input_tokens': 530, 'output_tokens': 67, 'duration': 1.1249363422393799}
# {'path': 'executive-order-10011-authorizing-the-secretary-state-exercise-certain-powers-the.json', 'input_tokens': 1269, 'output_tokens': 96, 'duration': 1.2274847030639648}
# {'path': 'executive-order-10013-establishing-the-presidents-committee-religious-and-moral-welfare.json', 'input_tokens': 652, 'output_tokens': 108, 'duration': 1.338439702987671}
# {'path': 'executive-order-10010-creating-emergency-board-investigate-disputes-between-the-akron.json', 'input_tokens': 2348, 'output_tokens': 123, 'duration': 1.4744501113891602}
# {'path': 'executive-order-10014-directing-federal-agencies-cooperate-with-sate-and-local-authorities.json', 'input_tokens': 487, 'output_tokens': 103, 'duration': 1.3219795227050781}
# {'path': 'executive-order-10015-amendment-executive-order-no-10010-creating-emergency-board.json', 'input_tokens': 543, 'output_tokens': 74, 'duration': 1.1557023525238037}
# {'path': 'executive-order-10016-coat-arms-seal-and-flag-the-vice-president-the-united-states.json', 'input_tokens': 784, 'output_tokens': 118, 'duration': 1.1142914295196533}
# {'path': 'executive-order-10017-amendment-the-regulations-governing-the-appointment-postmasters-the.json', 'input_tokens': 527, 'output_tokens': 79, 'duration': 1.2373123168945312}
# {'path': 'executive-order-10018-transferring-the-control-and-jurisdiction-over-certain-tracts-land.json', 'input_tokens': 1911, 'output_tokens': 78, 'duration': 1.3537888526916504}
# {'path': 'executive-order-10021-further-exemption-harry-b-mitchell-from-compulsory-retirement-for.json', 'input_tokens': 451, 'output_tokens': 73, 'duration': 1.160372257232666}
# {'path': 'executive-order-10019-excusing-federal-employees-from-duty-one-half-day-december-24-1948.json', 'input_tokens': 476, 'output_tokens': 102, 'duration': 1.4520349502563477}
# {'path': 'executive-order-10020-prescribing-the-manual-for-courts-martial-us-army-1949.json', 'input_tokens': 674, 'output_tokens': 100, 'duration': 1.4158012866973877}
# {'path': 'executive-order-10024-restoration-lands-location-and-entry-under-the-mining-laws-the.json', 'input_tokens': 489, 'output_tokens': 73, 'duration': 1.2647449970245361}
# {'path': 'executive-order-10022-transferring-the-use-possession-and-control-certain-lands-from-the.json', 'input_tokens': 623, 'output_tokens': 109, 'duration': 1.3542454242706299}
# {'path': 'executive-order-10023-amendment-executive-order-9984-july-31-1948-prescribing-regulations.json', 'input_tokens': 774, 'output_tokens': 75, 'duration': 1.3134596347808838}
# {'path': 'executive-order-10025-designating-public-international-organizations-entitled-enjoy.json', 'input_tokens': 586, 'output_tokens': 100, 'duration': 1.3367278575897217}
# {'path': 'executive-order-10026-korea.json', 'input_tokens': 266, 'output_tokens': 80, 'duration': 1.118619441986084}
# {'path': 'executive-order-10026-adopting-the-manual-for-courts-martial-us-army-1949-for-use-the.json', 'input_tokens': 2601, 'output_tokens': 124, 'duration': 1.5613982677459717}
# {'path': 'executive-order-10027-extension-trust-periods-indian-lands-expiring-during-the-calendar.json', 'input_tokens': 525, 'output_tokens': 114, 'duration': 1.5532245635986328}
# {'path': 'executive-order-10028-defining-noncombatant-service-and-noncombatant-training.json', 'input_tokens': 480, 'output_tokens': 152, 'duration': 1.5493929386138916}
# {'path': 'executive-order-10031-separation-officers-the-public-health-service-grounds-disloyalty.json', 'input_tokens': 670, 'output_tokens': 56, 'duration': 1.183253288269043}
# {'path': 'executive-order-10030-administration-and-supervision-the-district-columbia-national-guard.json', 'input_tokens': 525, 'output_tokens': 91, 'duration': 1.522125482559204}
# {'path': 'executive-order-10032-creating-emergency-board-investigate-dispute-between-the-akron.json', 'input_tokens': 1264, 'output_tokens': 106, 'duration': 1.3676114082336426}
# {'path': 'executive-order-10029-creating-emergency-board-investigate-dispute-between-the-northwest.json', 'input_tokens': 556, 'output_tokens': 151, 'duration': 1.6922008991241455}
# {'path': 'executive-order-10034-further-exemption-john-monroe-johnson-from-compulsory-retirement-for.json', 'input_tokens': 500, 'output_tokens': 73, 'duration': 1.115814447402954}
# {'path': 'executive-order-10033-regulations-governing-the-providing-statistical-information.json', 'input_tokens': 1122, 'output_tokens': 151, 'duration': 1.7227091789245605}
# {'path': 'executive-order-10036-restoration-lands-location-and-entry-under-the-mining-laws-the.json', 'input_tokens': 522, 'output_tokens': 80, 'duration': 1.1114280223846436}
# {'path': 'executive-order-10035-designating-the-honorable-luis-negron-fernandez-acting-judge-the.json', 'input_tokens': 463, 'output_tokens': 101, 'duration': 1.377798080444336}
# {'path': 'executive-order-10037-creating-emergency-board-investigate-dispute-between-the-denver-rio.json', 'input_tokens': 566, 'output_tokens': 144, 'duration': 1.53401517868042}
# {'path': 'executive-order-10039-authorizing-the-civil-service-commission-confer-competitive-status.json', 'input_tokens': 496, 'output_tokens': 82, 'duration': 1.1311686038970947}
# {'path': 'executive-order-10040-amendment-executive-order-no-9999-suspending-certain-statutory.json', 'input_tokens': 587, 'output_tokens': 77, 'duration': 1.2016677856445312}
# {'path': 'executive-order-10041-restoring-certain-lands-the-united-states-naval-reservation-hanapepe.json', 'input_tokens': 812, 'output_tokens': 71, 'duration': 1.0343387126922607}
# {'path': 'executive-order-10043-changing-the-name-the-presidents-committee-religious-and-moral.json', 'input_tokens': 389, 'output_tokens': 49, 'duration': 0.9015548229217529}
# {'path': 'executive-order-10038-creating-emergency-board-investigate-dispute-between-the-carriers.json', 'input_tokens': 584, 'output_tokens': 167, 'duration': 1.7334179878234863}
# {'path': 'executive-order-10042-making-certain-changes-the-customs-field-organization.json', 'input_tokens': 790, 'output_tokens': 79, 'duration': 1.2457947731018066}
# {'path': 'executive-order-10044-amendment-executive-order-no-9-january-17-1873-relating-the-holding.json', 'input_tokens': 489, 'output_tokens': 82, 'duration': 1.2379729747772217}
# {'path': 'executive-order-10046-transferring-certain-lands-from-the-department-agriculture-the.json', 'input_tokens': 11567, 'output_tokens': 71, 'duration': 1.1912405490875244}
# {'path': 'executive-order-10047-restoring-portion-honolulu-harbor-the-jurisdicton-the-territory.json', 'input_tokens': 1135, 'output_tokens': 67, 'duration': 1.101280689239502}
# {'path': 'executive-order-10045-creating-emergency-board-investigate-dispute-between-the-wabash.json', 'input_tokens': 580, 'output_tokens': 98, 'duration': 1.3413164615631104}
# {'path': 'executive-order-10048-creating-emergency-board-investigate-dispute-between-the-southern.json', 'input_tokens': 564, 'output_tokens': 103, 'duration': 1.1880741119384766}
# {'path': 'executive-order-10049-delegating-the-authority-the-president-prescribe-clothing-allowances.json', 'input_tokens': 586, 'output_tokens': 116, 'duration': 1.3631408214569092}
# {'path': 'executive-order-10050-creating-emergency-board-investigate-dispute-between-the-railway.json', 'input_tokens': 565, 'output_tokens': 125, 'duration': 1.3490550518035889}
# {'path': 'executive-order-10052-enlarging-naval-petroleum-reserve-no-1-revoking-part-public-land.json', 'input_tokens': 651, 'output_tokens': 138, 'duration': 1.351527214050293}
# {'path': 'executive-order-10054-modifying-executive-order-no-9721-providing-for-the-transfer.json', 'input_tokens': 502, 'output_tokens': 98, 'duration': 1.3210713863372803}
# {'path': 'executive-order-10051-creating-emergency-board-investigate-dispute-between-the-aliquippa.json', 'input_tokens': 567, 'output_tokens': 149, 'duration': 1.9027612209320068}
# {'path': 'executive-order-10055-amendment-executive-order-no-9-january-17-1873-relating-the-holding.json', 'input_tokens': 676, 'output_tokens': 124, 'duration': 1.380821943283081}
# {'path': 'executive-order-10053-regulations-governing-the-transportation-household-goods-members-the.json', 'input_tokens': 18292, 'output_tokens': 89, 'duration': 1.6642029285430908}
# {'path': 'executive-order-10057-transferring-the-american-battle-monuments-commission-functions.json', 'input_tokens': 897, 'output_tokens': 89, 'duration': 1.2640361785888672}
# {'path': 'executive-order-10058-restoring-certain-lands-keaukaha-waiakea-south-hilo-hawaii-the.json', 'input_tokens': 876, 'output_tokens': 98, 'duration': 1.210090160369873}
# {'path': 'executive-order-10056-creating-emergency-board-investigate-dispute-between-the-union.json', 'input_tokens': 564, 'output_tokens': 162, 'duration': 1.8152718544006348}
# {'path': 'executive-order-10059-amendment-executive-order-no-9195-july-7-1942-amended-prescribing.json', 'input_tokens': 971, 'output_tokens': 60, 'duration': 1.1915392875671387}
# {'path': 'executive-order-10061-amendment-executive-order-no-9871-amended-prescribing-regulations.json', 'input_tokens': 883, 'output_tokens': 73, 'duration': 1.0554463863372803}
# {'path': 'executive-order-10060-restoring-certain-land-comprising-the-keaahala-military-reservation.json', 'input_tokens': 587, 'output_tokens': 89, 'duration': 1.121203899383545}
# {'path': 'executive-order-10062-establishing-the-position-united-states-high-commissioner-for.json', 'input_tokens': 742, 'output_tokens': 98, 'duration': 1.2785542011260986}
# {'path': 'executive-order-10065-termination-the-office-defense-transportation.json', 'input_tokens': 721, 'output_tokens': 87, 'duration': 1.3500785827636719}
# {'path': 'executive-order-10063-defining-certain-functions-the-united-states-high-commissioner-for.json', 'input_tokens': 492, 'output_tokens': 208, 'duration': 2.0045692920684814}
# {'path': 'executive-order-10068-revoking-order-no-2458-or-september-20-1916-establishing-inter.json', 'input_tokens': 348, 'output_tokens': 81, 'duration': 1.266488790512085}
# {'path': 'executive-order-10067-creating-emergency-board-investigate-dispute-between-the-missouri.json', 'input_tokens': 581, 'output_tokens': 130, 'duration': 1.4719040393829346}
# {'path': 'executive-order-10066-including-certain-lands-the-cherokee-national-forest.json', 'input_tokens': 743, 'output_tokens': 139, 'duration': 1.6728360652923584}
# {'path': 'executive-order-10069-amendment-executive-order-no-9805-prescribing-regulaitons-governing.json', 'input_tokens': 858, 'output_tokens': 112, 'duration': 1.3875141143798828}
# {'path': 'executive-order-10064-further-extension-executive-order-no-9898-october-14-1947-amended.json', 'input_tokens': 735, 'output_tokens': 143, 'duration': 2.027254581451416}
# {'path': 'executive-order-10070-amending-executive-order-no-9975-july-7-1948-prescribing-regulations.json', 'input_tokens': 576, 'output_tokens': 93, 'duration': 1.2569029331207275}
# {'path': 'executive-order-10071-creating-emergency-board-investigate-dispute-between-the-southern.json', 'input_tokens': 559, 'output_tokens': 114, 'duration': 1.3640110492706299}
# {'path': 'executive-order-10074-transfer-the-district-land-office-carson-city-nevada-reno-nevada.json', 'input_tokens': 422, 'output_tokens': 75, 'duration': 1.0417735576629639}
# {'path': 'executive-order-10073-exemption-eugene-black-from-compulsory-retirement-for-age.json', 'input_tokens': 463, 'output_tokens': 90, 'duration': 1.0612072944641113}
# {'path': 'executive-order-10072-provide-for-continuing-action-improve-the-management-the-executive.json', 'input_tokens': 752, 'output_tokens': 88, 'duration': 1.2306177616119385}
# {'path': 'executive-order-10075-eliminating-certain-public-lands-from-naval-petroleum-reserve-no-2.json', 'input_tokens': 854, 'output_tokens': 109, 'duration': 1.2327837944030762}
# {'path': 'executive-order-10078-creating-emergency-board-investigate-dispute-between-the-monongahela.json', 'input_tokens': 584, 'output_tokens': 102, 'duration': 1.2893421649932861}
# {'path': 'executive-order-10077-transfer-the-administration-the-island-guam-from-the-secretary-the.json', 'input_tokens': 765, 'output_tokens': 94, 'duration': 1.535658597946167}
# {'path': 'executive-order-10076-inspection-income-excess-profits-and-declared-value-excess-profits.json', 'input_tokens': 475, 'output_tokens': 112, 'duration': 1.6179261207580566}
# {'path': 'executive-order-10079-transferring-certain-property-the-virgin-islands-the-permanent.json', 'input_tokens': 615, 'output_tokens': 92, 'duration': 1.307694911956787}
# {'path': 'executive-order-10080-enabling-certain-employees-the-federal-government-acquire.json', 'input_tokens': 659, 'output_tokens': 101, 'duration': 1.2109599113464355}
# {'path': 'executive-order-10082-prescribing-procedures-for-the-administration-the-reciprocal-trade.json', 'input_tokens': 2635, 'output_tokens': 71, 'duration': 1.3030428886413574}
# {'path': 'executive-order-10081-designation-certain-officers-act-postmaster-general.json', 'input_tokens': 460, 'output_tokens': 94, 'duration': 1.463325023651123}
# {'path': 'executive-order-10086-designating-the-south-pacific-commission-public-international.json', 'input_tokens': 455, 'output_tokens': 85, 'duration': 1.0179212093353271}
# {'path': 'executive-order-10083-revocation-executive-orders-nos-9698-9751-and-9823-so-far-they.json', 'input_tokens': 517, 'output_tokens': 112, 'duration': 1.6626551151275635}
# {'path': 'executive-order-10085-amendment-executive-order-no-10011-authorizing-the-secretary-state.json', 'input_tokens': 574, 'output_tokens': 74, 'duration': 1.3422489166259766}
# {'path': 'executive-order-10084-prescribing-regulations-for-the-administration-certain-provisions.json', 'input_tokens': 462, 'output_tokens': 133, 'duration': 1.5162227153778076}
# {'path': 'executive-order-10087-amendment-executive-order-no-10057-may-14-1949-transferring-the.json', 'input_tokens': 908, 'output_tokens': 87, 'duration': 1.1433610916137695}
# {'path': 'executive-order-10088-making-certain-changes-the-customs-field-organization.json', 'input_tokens': 525, 'output_tokens': 88, 'duration': 1.3560729026794434}
# {'path': 'executive-order-10089-suspending-certain-statutory-provisions-relating-employment-the.json', 'input_tokens': 484, 'output_tokens': 103, 'duration': 1.2454640865325928}
# {'path': 'executive-order-10090-inspection-income-tax-returns-federal-trade-commission.json', 'input_tokens': 534, 'output_tokens': 157, 'duration': 1.5552000999450684}
# {'path': 'executive-order-10092-establishing-airspace-reservation-over-certain-areas-the-superior.json', 'input_tokens': 3508, 'output_tokens': 112, 'duration': 1.2615442276000977}
# {'path': 'executive-order-10093-revocation-executive-order-no-9512-january-16-1945-providing-for.json', 'input_tokens': 349, 'output_tokens': 71, 'duration': 1.2478141784667969}
# {'path': 'executive-order-10091-extension-trust-periods-indian-lands-expiring-during-the-calendar.json', 'input_tokens': 508, 'output_tokens': 168, 'duration': 1.7397851943969727}
# {'path': 'executive-order-10095-establishment-the-presidents-water-resources-policy-commission.json', 'input_tokens': 895, 'output_tokens': 107, 'duration': 1.2638096809387207}
# {'path': 'executive-order-10094-further-exemption-clyde-b-aitchison-from-compulsory-retirement-for.json', 'input_tokens': 542, 'output_tokens': 130, 'duration': 1.5399935245513916}
# {'path': 'executive-order-10097-designating-the-honorable-cecil-snyder-acting-judge-the-united.json', 'input_tokens': 479, 'output_tokens': 84, 'duration': 1.1763947010040283}
# {'path': 'executive-order-10098-amendment-executive-order-no-10084-october-12-1949-prescribing.json', 'input_tokens': 435, 'output_tokens': 68, 'duration': 1.2518954277038574}
# {'path': 'executive-order-10099-providing-for-the-administration-the-mutual-defense-assistance-act.json', 'input_tokens': 832, 'output_tokens': 95, 'duration': 1.2641856670379639}
# {'path': 'executive-order-101.json', 'input_tokens': 416, 'output_tokens': 114, 'duration': 1.2021892070770264}
# {'path': 'executive-order-10100-regulations-relating-the-granting-certain-allowances-the-director.json', 'input_tokens': 568, 'output_tokens': 77, 'duration': 1.0159151554107666}
# {'path': 'executive-order-10096-providing-for-uniform-patent-policy-for-the-government-with-respect.json', 'input_tokens': 2386, 'output_tokens': 140, 'duration': 1.9593236446380615}
# {'path': 'executive-order-10102-transfer-certain-business-operations-facilities-and-appurtenances.json', 'input_tokens': 1475, 'output_tokens': 88, 'duration': 1.060088872909546}
# {'path': 'executive-order-10101-amendment-executive-order-no-9746-july-1-1946-relating-the-panama.json', 'input_tokens': 718, 'output_tokens': 83, 'duration': 1.1667571067810059}
# {'path': 'executive-order-10103-amendment-executive-order-no-9721-may-10-1946-providing-for-the.json', 'input_tokens': 812, 'output_tokens': 117, 'duration': 1.4406096935272217}
# {'path': 'executive-order-10104-defining-certain-vital-military-and-naval-installations-and.json', 'input_tokens': 1364, 'output_tokens': 108, 'duration': 1.2345185279846191}
# {'path': 'executive-order-10107-revocation-executive-order-no-8232-september-5-1939-relating-the.json', 'input_tokens': 372, 'output_tokens': 88, 'duration': 1.0634126663208008}
# {'path': 'executive-order-10105-creating-emergency-board-investigate-dispute-between-the-denver-and.json', 'input_tokens': 559, 'output_tokens': 91, 'duration': 1.1879043579101562}
# {'path': 'executive-order-10106-creating-board-inquiry-report-labor-dispute-affecting-the-bituminous.json', 'input_tokens': 563, 'output_tokens': 126, 'duration': 1.4627470970153809}
# {'path': 'executive-order-10108-designating-the-united-states-mission-the-united-nations-and.json', 'input_tokens': 851, 'output_tokens': 149, 'duration': 1.4792335033416748}
# {'path': 'executive-order-10109-creating-emergency-board-investigate-disputes-between-the-texas.json', 'input_tokens': 626, 'output_tokens': 112, 'duration': 1.381164312362671}
# {'path': 'executive-order-10110-presidents-communications-policy-board.json', 'input_tokens': 839, 'output_tokens': 109, 'duration': 1.6850922107696533}
# {'path': 'executive-order-10113-delegating-the-authority-the-president-prescribe-clothing-allowances.json', 'input_tokens': 773, 'output_tokens': 77, 'duration': 0.9539976119995117}
# {'path': 'executive-order-10111-establishing-seal-for-the-central-intelligence-agency.json', 'input_tokens': 584, 'output_tokens': 84, 'duration': 1.3688819408416748}
# {'path': 'executive-order-10114-creating-emergency-board-investigate-dispute-between-the-terminal.json', 'input_tokens': 568, 'output_tokens': 110, 'duration': 1.2384581565856934}
# {'path': 'executive-order-10115-restoring-certain-land-reserved-for-military-purposes-the.json', 'input_tokens': 1107, 'output_tokens': 100, 'duration': 1.3690366744995117}
# {'path': 'executive-order-10112-creating-emergency-board-investigate-dispute-betweent-the-carriers.json', 'input_tokens': 595, 'output_tokens': 150, 'duration': 1.9445478916168213}
# {'path': 'executive-order-10116-amending-portions-the-selective-service-regulations-and-paragraph-2.json', 'input_tokens': 4174, 'output_tokens': 112, 'duration': 1.5812301635742188}
# {'path': 'executive-order-10119-regulations-governing-the-payment-basic-allowances-for-subsistence.json', 'input_tokens': 1179, 'output_tokens': 84, 'duration': 1.178589105606079}
# {'path': 'executive-order-10118-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 545, 'output_tokens': 86, 'duration': 1.4500045776367188}
# {'path': 'executive-order-10121-transferring-the-territory-hawaii-title-certain-public-land-needed.json', 'input_tokens': 4587, 'output_tokens': 83, 'duration': 1.101288080215454}
# {'path': 'executive-order-10117-creating-emergency-board-investigate-dispute-between-the-carriers.json', 'input_tokens': 558, 'output_tokens': 160, 'duration': 2.0546250343322754}
# {'path': 'executive-order-10120-creating-emergency-board-investigate-dispute-between-the-carriers.json', 'input_tokens': 589, 'output_tokens': 109, 'duration': 1.4748039245605469}
# {'path': 'executive-order-10123-revocation-executive-order-no-9635-september-29-1945-and-no-9904.json', 'input_tokens': 474, 'output_tokens': 63, 'duration': 1.0277371406555176}
# {'path': 'executive-order-10122-regulations-governing-payment-disability-retirement-pay.json', 'input_tokens': 1527, 'output_tokens': 86, 'duration': 1.2763750553131104}
# {'path': 'executive-order-10124-regulations-governing-the-election-certain-members-and-former.json', 'input_tokens': 911, 'output_tokens': 84, 'duration': 1.018996000289917}
# {'path': 'executive-order-10126-establishing-airspace-reservation-over-portions-the-district.json', 'input_tokens': 864, 'output_tokens': 90, 'duration': 1.1618952751159668}
# {'path': 'executive-order-10125-creating-emergency-board-investigate-dispute-between-the-chicago.json', 'input_tokens': 559, 'output_tokens': 107, 'duration': 1.4285807609558105}
# {'path': 'executive-order-10128-amendment-executive-order-no-6868-october-9-1934-amended-designating.json', 'input_tokens': 477, 'output_tokens': 77, 'duration': 1.0897901058197021}
# {'path': 'executive-order-10127-establishing-airspace-reservations-over-certain-facilities-the.json', 'input_tokens': 1052, 'output_tokens': 91, 'duration': 1.399536371231079}
# {'path': 'executive-order-10129-establishing-the-presidents-commission-migratory-labor.json', 'input_tokens': 966, 'output_tokens': 145, 'duration': 1.6112143993377686}
# {'path': 'executive-order-10130-creating-emergency-board-investigate-dispute-between-the-boston.json', 'input_tokens': 567, 'output_tokens': 106, 'duration': 1.2747130393981934}
# {'path': 'executive-order-10132-inspection-income-excess-profits-declared-value-excess-profits.json', 'input_tokens': 521, 'output_tokens': 95, 'duration': 1.2114989757537842}
# {'path': 'executive-order-10133-designating-the-organization-for-european-economic-cooperation.json', 'input_tokens': 405, 'output_tokens': 99, 'duration': 1.0917792320251465}
# {'path': 'executive-order-10135-further-extension-executive-order-no-9898-october-14-1947-amended.json', 'input_tokens': 759, 'output_tokens': 66, 'duration': 0.937272310256958}
# {'path': 'executive-order-10136-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 580, 'output_tokens': 72, 'duration': 0.9582614898681641}
# {'path': 'executive-order-10131-providing-for-the-investigation-and-report-displaced-pesons-and.json', 'input_tokens': 595, 'output_tokens': 140, 'duration': 1.7485909461975098}
# {'path': 'executive-order-10134-further-extension-the-existence-the-quetico-superior-committee.json', 'input_tokens': 448, 'output_tokens': 72, 'duration': 1.2984869480133057}
# {'path': 'executive-order-10137-amending-executive-order-no-10077-september-7-1949-entitled-transfer.json', 'input_tokens': 435, 'output_tokens': 107, 'duration': 1.2813665866851807}
# {'path': 'executive-order-10138-creating-emergency-board-investigate-dispute-between-the-toledo.json', 'input_tokens': 572, 'output_tokens': 111, 'duration': 1.3448076248168945}
# {'path': 'executive-order-10139-creating-emergency-board-investigate-dispute-between-the-toledo.json', 'input_tokens': 570, 'output_tokens': 164, 'duration': 1.6040449142456055}
# {'path': 'executive-order-10140-creating-emergency-board-investigate-dispute-between-the-pullman.json', 'input_tokens': 546, 'output_tokens': 129, 'duration': 1.420668125152588}
# {'path': 'executive-order-10141-possession-control-and-operation-the-transportation-system-the.json', 'input_tokens': 1513, 'output_tokens': 111, 'duration': 1.4790143966674805}
# {'path': 'executive-order-10142-creating-emergency-board-investigate-dispute-between-the-braniff.json', 'input_tokens': 568, 'output_tokens': 105, 'duration': 1.3370273113250732}
# {'path': 'executive-order-10143-authorizing-the-appointment-mrs-ruth-edna-mcc-somers-position-the.json', 'input_tokens': 401, 'output_tokens': 94, 'duration': 1.4076998233795166}
# {'path': 'executive-order-10144-amendment-executive-order-no-10062-june-6-1949-establishing-the.json', 'input_tokens': 558, 'output_tokens': 156, 'duration': 1.464367151260376}
# {'path': 'executive-order-10146-exemption-william-j-pattersn-from-compulsory-retirement-for-age.json', 'input_tokens': 495, 'output_tokens': 97, 'duration': 1.1895239353179932}
# {'path': 'executive-order-10145-extension-enlistements-the-armed-forces-the-united-states.json', 'input_tokens': 488, 'output_tokens': 115, 'duration': 1.4193923473358154}
# {'path': 'executive-order-10148-designation-certain-officers-the-department-commerce-act-secretary.json', 'input_tokens': 543, 'output_tokens': 87, 'duration': 1.1030051708221436}
# {'path': 'executive-order-10151-exemption-william-d-hassett-from-compulsory-retirement-for-age.json', 'input_tokens': 459, 'output_tokens': 75, 'duration': 1.0169434547424316}
# {'path': 'executive-order-10147-creating-emergency-board-investigate-dispute-between-the-new-york.json', 'input_tokens': 589, 'output_tokens': 115, 'duration': 1.3538470268249512}
# {'path': 'executive-order-10150-creating-emergency-board-investigate-disputes-between-the-atlantic.json', 'input_tokens': 985, 'output_tokens': 91, 'duration': 1.5114333629608154}
# {'path': 'executive-order-10152-regulations-relating-the-right-members-the-uniformed-services.json', 'input_tokens': 2667, 'output_tokens': 100, 'duration': 1.2577292919158936}
# {'path': 'executive-order-10149-suspending-the-limitations-upon-punishments-for-violations-articles.json', 'input_tokens': 555, 'output_tokens': 122, 'duration': 1.70815110206604}
# {'path': 'executive-order-10153-regulations-relating-certain-travel-time-members-the-uniformed.json', 'input_tokens': 714, 'output_tokens': 93, 'duration': 1.122736930847168}
# {'path': 'executive-order-10154-designation-certain-officers-the-post-office-department-act.json', 'input_tokens': 449, 'output_tokens': 93, 'duration': 1.0439200401306152}
# {'path': 'executive-order-10156-designation-certain-officers-the-department-the-interior-act.json', 'input_tokens': 578, 'output_tokens': 82, 'duration': 0.9910337924957275}
# {'path': 'executive-order-10157-enabling-certain-employees-the-federal-government-acquire.json', 'input_tokens': 760, 'output_tokens': 91, 'duration': 1.247495174407959}
# {'path': 'executive-order-10155-possession-control-and-operation-certain-railroads.json', 'input_tokens': 5398, 'output_tokens': 137, 'duration': 1.471343994140625}
# {'path': 'executive-order-10158-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 530, 'output_tokens': 71, 'duration': 1.1816349029541016}
# {'path': 'executive-order-10159-providing-for-the-administration-the-act-for-international.json', 'input_tokens': 658, 'output_tokens': 93, 'duration': 1.1999773979187012}
# {'path': 'executive-order-10162-authorizing-the-appointment-frederick-c-kilguss-the-position-deputy.json', 'input_tokens': 380, 'output_tokens': 90, 'duration': 1.4730618000030518}
# {'path': 'executive-order-10163-the-armed-forces-reserve-medal.json', 'input_tokens': 904, 'output_tokens': 97, 'duration': 1.2386329174041748}
# {'path': 'executive-order-10164-extension-enlistments-the-united-states-coast-guard.json', 'input_tokens': 518, 'output_tokens': 84, 'duration': 1.1463797092437744}
# {'path': 'executive-order-10160-providing-for-the-preservation-records-for-certain-purposes-the.json', 'input_tokens': 842, 'output_tokens': 136, 'duration': 1.8598361015319824}
# {'path': 'executive-order-10161-delegating-certain-functions-the-president-under-the-defense.json', 'input_tokens': 5365, 'output_tokens': 158, 'duration': 2.0101170539855957}
# {'path': 'executive-order-10167-prescribing-or-amending-portions-the-selective-service-regulations.json', 'input_tokens': 6465, 'output_tokens': 108, 'duration': 1.2513136863708496}
# {'path': 'executive-order-10165-creating-emergency-board-investigate-dispute-between-the-railway.json', 'input_tokens': 585, 'output_tokens': 137, 'duration': 1.5802836418151855}
# {'path': 'executive-order-10166-establishing-the-national-advisory-committee-the-selection-doctors.json', 'input_tokens': 827, 'output_tokens': 121, 'duration': 1.349958896636963}
# {'path': 'executive-order-10168-regulations-relating-the-right-enlisted-members-the-uniformed.json', 'input_tokens': 1361, 'output_tokens': 79, 'duration': 1.3272886276245117}
# {'path': 'executive-order-10170-amendment-executive-order-no-10082-october-5-1949-prescribing.json', 'input_tokens': 582, 'output_tokens': 111, 'duration': 1.258537769317627}
# {'path': 'executive-order-10171-transferring-occupation-functions-austria-the-department-state.json', 'input_tokens': 814, 'output_tokens': 93, 'duration': 1.2809867858886719}
# {'path': 'executive-order-10172-designating-the-certifying-authority-with-respect-the-amortization.json', 'input_tokens': 495, 'output_tokens': 79, 'duration': 1.1629564762115479}
# {'path': 'executive-order-10169-establishing-the-national-advisory-committee-mobilization-policy.json', 'input_tokens': 535, 'output_tokens': 192, 'duration': 1.7771093845367432}
# {'path': 'executive-order-10173-regulations-relating-the-safeguarding-vessels-harbors-ports-and.json', 'input_tokens': 3005, 'output_tokens': 85, 'duration': 1.234816074371338}
# {'path': 'executive-order-10174-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 544, 'output_tokens': 71, 'duration': 1.2379264831542969}
# {'path': 'executive-order-10175-amending-executive-order-no-7908-june-9-1938-and-executive-order-no.json', 'input_tokens': 857, 'output_tokens': 94, 'duration': 1.4554638862609863}
# {'path': 'executive-order-10176-suspending-certain-statutory-provisions-relating-employment-the.json', 'input_tokens': 463, 'output_tokens': 107, 'duration': 1.2481179237365723}
# {'path': 'executive-order-10178-reserving-certain-real-and-personal-property-guam-for-the-use-the.json', 'input_tokens': 1606, 'output_tokens': 91, 'duration': 1.1015613079071045}
# {'path': 'executive-order-10177-amendment-section-1-executive-order-no-9778-september-10-1946.json', 'input_tokens': 694, 'output_tokens': 86, 'duration': 1.3281712532043457}
# {'path': 'executive-order-10181-delegating-the-director-the-bureau-the-budget-the-function.json', 'input_tokens': 388, 'output_tokens': 70, 'duration': 1.031498670578003}
# {'path': 'executive-order-10182-providing-for-the-appointment-certain-persons-under-the-defense.json', 'input_tokens': 1761, 'output_tokens': 80, 'duration': 1.1037671566009521}
# {'path': 'executive-order-10180-establishing-special-personnel-procedures-the-interest-the-national.json', 'input_tokens': 1102, 'output_tokens': 128, 'duration': 1.4662954807281494}
# {'path': 'executive-order-10179-establishing-the-korean-service-medal.json', 'input_tokens': 527, 'output_tokens': 174, 'duration': 1.6585111618041992}
# {'path': 'executive-order-10183-making-certain-changes-internal-revenue-collection-districts-the.json', 'input_tokens': 538, 'output_tokens': 92, 'duration': 1.1378719806671143}
# {'path': 'executive-order-10185-amendment-executive-order-no-10166-october-4-1950.json', 'input_tokens': 567, 'output_tokens': 68, 'duration': 0.9360613822937012}
# {'path': 'executive-order-10184-transferring-certain-land-comprising-portion-the-arecibo-coast-guard.json', 'input_tokens': 715, 'output_tokens': 99, 'duration': 1.1253712177276611}
# {'path': 'executive-order-10187-amendment-executive-order-no-10011-october-22-1948-amended.json', 'input_tokens': 615, 'output_tokens': 76, 'duration': 1.0391781330108643}
# {'path': 'executive-order-10188-designating-the-honorable-luis-negron-fernandez-acting-judge-the.json', 'input_tokens': 479, 'output_tokens': 76, 'duration': 1.1415984630584717}
# {'path': 'executive-order-10186-establishing-the-federal-civil-defense-administration-the-office-for.json', 'input_tokens': 1471, 'output_tokens': 102, 'duration': 1.4492518901824951}
# {'path': 'executive-order-10190-prescribing-regulations-relating-new-trials-courts-martial-and-other.json', 'input_tokens': 1752, 'output_tokens': 72, 'duration': 1.0163335800170898}
# {'path': 'executive-order-10192-amendment-executive-order-no-10129-june-3-1950-entitled-estblishing.json', 'input_tokens': 369, 'output_tokens': 63, 'duration': 0.993821382522583}
# {'path': 'executive-order-10193-providing-for-the-conduct-the-mobilization-effort-the-government.json', 'input_tokens': 749, 'output_tokens': 73, 'duration': 1.1052942276000977}
# {'path': 'executive-order-10191-extension-trust-periods-indian-lands-expiring-during-the-calendar.json', 'input_tokens': 508, 'output_tokens': 109, 'duration': 1.526350975036621}
# {'path': 'executive-order-10189-amendment-executive-order-no-4601-march-1-1927-prescribing.json', 'input_tokens': 923, 'output_tokens': 128, 'duration': 1.9221546649932861}
# {'path': 'executive-order-10196-amendment-executive-order-9805-prescribing-regulations-governing.json', 'input_tokens': 2240, 'output_tokens': 91, 'duration': 1.0977380275726318}
# {'path': 'executive-order-10194-establishing-the-federal-safety-council.json', 'input_tokens': 986, 'output_tokens': 125, 'duration': 1.4456708431243896}
# {'path': 'executive-order-10195-designation-korea-and-waters-adjacent-thereto-combat-zone-for-the.json', 'input_tokens': 597, 'output_tokens': 116, 'duration': 1.4171311855316162}
# {'path': 'executive-order-10199-authorizing-the-secretary-agriculture-make-without-the-approval-the.json', 'input_tokens': 386, 'output_tokens': 71, 'duration': 0.9677510261535645}
# {'path': 'executive-order-102.json', 'input_tokens': 345, 'output_tokens': 87, 'duration': 1.0955514907836914}
# {'path': 'executive-order-10198-exemption-paul-walker-from-compulsory-retirement-for-age.json', 'input_tokens': 475, 'output_tokens': 159, 'duration': 1.4521701335906982}
# {'path': 'executive-order-10197-directing-the-secretary-commerce-exercise-security-control-over.json', 'input_tokens': 439, 'output_tokens': 122, 'duration': 1.6881999969482422}
# {'path': 'executive-order-10200-establishing-the-defense-production-administration.json', 'input_tokens': 2190, 'output_tokens': 87, 'duration': 1.0913846492767334}
# {'path': 'executive-order-10201-attaching-the-virgin-islands-the-internal-revenue-collection.json', 'input_tokens': 368, 'output_tokens': 91, 'duration': 1.0507326126098633}
# {'path': 'executive-order-10202-prescribing-or-amending-portions-the-selective-service-regulations.json', 'input_tokens': 5945, 'output_tokens': 62, 'duration': 1.211857557296753}
# {'path': 'executive-order-10205-amending-executive-order-no-10182-relating-the-appointment-certain.json', 'input_tokens': 659, 'output_tokens': 82, 'duration': 1.1047272682189941}
# {'path': 'executive-order-10206-providing-for-support-united-nations-activities-directed-the.json', 'input_tokens': 778, 'output_tokens': 89, 'duration': 1.1759092807769775}
# {'path': 'executive-order-10207-establishing-the-presidents-commission-internal-security-and.json', 'input_tokens': 893, 'output_tokens': 131, 'duration': 1.2744975090026855}
# {'path': 'executive-order-10208-providing-for-the-administration-the-yugoslav-emergency-relief.json', 'input_tokens': 506, 'output_tokens': 91, 'duration': 1.0694644451141357}
# {'path': 'executive-order-10203-creating-emergency-board-investigate-dispute-between-the-american.json', 'input_tokens': 556, 'output_tokens': 168, 'duration': 1.7358543872833252}
# {'path': 'executive-order-10204-prescribing-regulations-governing-the-payment-basic-allowances-for.json', 'input_tokens': 1148, 'output_tokens': 125, 'duration': 1.6233737468719482}
# {'path': 'executive-order-10209-amending-executive-order-no-8557-september-30-1940-entitled.json', 'input_tokens': 441, 'output_tokens': 162, 'duration': 1.5702300071716309}
# {'path': 'executive-order-10210-authorizing-the-department-defense-and-the-department-commerce.json', 'input_tokens': 2027, 'output_tokens': 136, 'duration': 1.5072524547576904}
# {'path': 'executive-order-10212-transferring-the-use-possession-and-control-certain-lands-and-rights.json', 'input_tokens': 3589, 'output_tokens': 75, 'duration': 1.0136473178863525}
# {'path': 'executive-order-10211-placing-operation-the-provisions-section-31-the-organic-act-guam.json', 'input_tokens': 573, 'output_tokens': 121, 'duration': 1.3662781715393066}
# {'path': 'executive-order-10213-including-certain-lands-the-nantahala-and-cherokee-national-forests.json', 'input_tokens': 19974, 'output_tokens': 67, 'duration': 1.2711446285247803}
# {'path': 'executive-order-10216-extension-the-provisions-part-i-executive-order-no-10210-february-2.json', 'input_tokens': 649, 'output_tokens': 128, 'duration': 1.242302417755127}
# {'path': 'executive-order-10215-exemption-arthur-quinn-from-compulsory-retirement-for-age.json', 'input_tokens': 452, 'output_tokens': 139, 'duration': 1.553154706954956}
# {'path': 'executive-order-10217-amending-paragraph-1c-executive-order-no-10157-august-28-1950.json', 'input_tokens': 493, 'output_tokens': 118, 'duration': 1.250840663909912}
# {'path': 'executive-order-10219-defining-certain-responsibilities-federal-agencies-with-respect.json', 'input_tokens': 2046, 'output_tokens': 125, 'duration': 1.245912790298462}
# {'path': 'executive-order-10220-authorizing-the-appointment-stanley-c-wollaston-competitive-position.json', 'input_tokens': 364, 'output_tokens': 75, 'duration': 1.0383727550506592}
# {'path': 'executive-order-10214-prescribing-the-manual-for-courts-martial-united-states-1951.json', 'input_tokens': 64146, 'output_tokens': 150, 'duration': 2.1377339363098145}
# {'path': 'executive-order-10218-establishing-airspace-reservation-over-the-las-vegas-project-las.json', 'input_tokens': 599, 'output_tokens': 108, 'duration': 1.5409166812896729}
# {'path': 'executive-order-10221-providing-for-the-administration-disaster-relief.json', 'input_tokens': 650, 'output_tokens': 103, 'duration': 1.1367449760437012}
# {'path': 'executive-order-10223-further-providing-for-the-performance-certain-functions-under-the.json', 'input_tokens': 507, 'output_tokens': 116, 'duration': 1.2340364456176758}
# {'path': 'executive-order-10225-exemption-bernice-pyke-from-compulsory-retirement-for-age.json', 'input_tokens': 481, 'output_tokens': 95, 'duration': 1.124596357345581}
# {'path': 'executive-order-10222-providing-for-certain-transfers-the-federal-civil-defense.json', 'input_tokens': 532, 'output_tokens': 194, 'duration': 2.0416808128356934}
# {'path': 'executive-order-10227-extension-the-provisions-part-i-executive-order-no-10210-february-2.json', 'input_tokens': 616, 'output_tokens': 100, 'duration': 1.2198970317840576}
# {'path': 'executive-order-10224-establishing-the-national-advisory-board-mobilization-policy.json', 'input_tokens': 733, 'output_tokens': 124, 'duration': 1.5557098388671875}
# {'path': 'executive-order-10226-regulations-relating-the-safeguarding-vessels-harbors-ports-and.json', 'input_tokens': 1920, 'output_tokens': 109, 'duration': 1.386829137802124}
# {'path': 'executive-order-10229-exemption-hugh-h-bennett-from-compulsory-retirement-for-age.json', 'input_tokens': 477, 'output_tokens': 90, 'duration': 1.3507966995239258}
# {'path': 'executive-order-10228-designating-the-inter-american-defense-board-public-international.json', 'input_tokens': 384, 'output_tokens': 126, 'duration': 1.5733880996704102}
# {'path': 'executive-order-10231-extension-the-provisions-part-i-executive-order-no-10210-february-2.json', 'input_tokens': 615, 'output_tokens': 106, 'duration': 1.1333470344543457}
# {'path': 'executive-order-10230-amending-the-selective-service-regulations.json', 'input_tokens': 1247, 'output_tokens': 154, 'duration': 1.5704286098480225}
# {'path': 'executive-order-10234-transferring-certain-lands-from-the-department-agriculture-the.json', 'input_tokens': 4693, 'output_tokens': 59, 'duration': 1.0494608879089355}
# {'path': 'executive-order-10236-amendment-executive-order-no-10129-june-3-1950-establishing-the.json', 'input_tokens': 409, 'output_tokens': 66, 'duration': 0.9141957759857178}
# {'path': 'executive-order-10232-amending-the-selective-service-regulations.json', 'input_tokens': 2202, 'output_tokens': 102, 'duration': 1.2957804203033447}
# {'path': 'executive-order-10235-establishing-seal-for-the-economic-stabilization-agency.json', 'input_tokens': 460, 'output_tokens': 100, 'duration': 1.2293331623077393}
# {'path': 'executive-order-10233-amending-executive-order-10161-with-respect-wage-stabilization-and.json', 'input_tokens': 1534, 'output_tokens': 182, 'duration': 1.845463514328003}
# {'path': 'executive-order-10239-exemption-howell-cone-from-compulsory-retirement-for-age.json', 'input_tokens': 468, 'output_tokens': 73, 'duration': 0.9643549919128418}
# {'path': 'executive-order-10237-making-the-provisions-the-act-august-26-1950-public-law-733-81st.json', 'input_tokens': 479, 'output_tokens': 131, 'duration': 1.454688310623169}
# {'path': 'executive-order-10240-regulations-governing-the-separation-from-the-service-certain-women.json', 'input_tokens': 712, 'output_tokens': 95, 'duration': 1.119248867034912}
# {'path': 'executive-order-10238-making-certain-changes-the-customs-field-organization.json', 'input_tokens': 516, 'output_tokens': 132, 'duration': 1.3611764907836914}
# {'path': 'executive-order-10242-prescribing-regulations-governing-the-exercise-the-federal-civil.json', 'input_tokens': 2150, 'output_tokens': 81, 'duration': 1.0996136665344238}
# {'path': 'executive-order-10243-extension-the-provisions-part-i-executive-order-no-10210-february-2.json', 'input_tokens': 691, 'output_tokens': 73, 'duration': 1.1293275356292725}
# {'path': 'executive-order-10241-amending-executive-order-no-9835-entitled-prescribing-procedures-for.json', 'input_tokens': 491, 'output_tokens': 109, 'duration': 1.2825148105621338}
# {'path': 'executive-order-10246-transferring-the-use-possession-and-control-certain-land-from-the.json', 'input_tokens': 891, 'output_tokens': 64, 'duration': 0.9065134525299072}
# {'path': 'executive-order-10244-designating-the-secretary-state-and-the-attorney-general-the.json', 'input_tokens': 835, 'output_tokens': 92, 'duration': 1.1184380054473877}
# {'path': 'executive-order-10247-suspending-the-limitations-upon-punishments-for-violations-articles.json', 'input_tokens': 513, 'output_tokens': 73, 'duration': 0.9215776920318604}
# {'path': 'executive-order-10248-transfer-certain-lands-from-the-sacramento-california-land-district.json', 'input_tokens': 1102, 'output_tokens': 75, 'duration': 0.9996671676635742}
# {'path': 'executive-order-10249-prescribing-regulations-with-respect-foreign-service-reporting.json', 'input_tokens': 769, 'output_tokens': 81, 'duration': 1.2006096839904785}
# {'path': 'executive-order-10245-establishing-commission-for-the-commemoration-the-one-hundred-and.json', 'input_tokens': 747, 'output_tokens': 160, 'duration': 1.6183748245239258}
# {'path': 'executive-order-10250-providing-for-the-performance-certain-functions-the-president-the.json', 'input_tokens': 2656, 'output_tokens': 87, 'duration': 1.2280924320220947}
# {'path': 'executive-order-10252-attaching-the-canal-zone-the-internal-revenue-collection-district.json', 'input_tokens': 368, 'output_tokens': 83, 'duration': 1.0859286785125732}
# {'path': 'executive-order-10251-suspension-the-eight-hour-law-laborers-and-mechanics-employed-the.json', 'input_tokens': 819, 'output_tokens': 129, 'duration': 1.4655170440673828}
# {'path': 'executive-order-10254-terminating-the-philippine-alien-property-administration-and.json', 'input_tokens': 850, 'output_tokens': 82, 'duration': 1.072679042816162}
# {'path': 'executive-order-10255-further-exemption-claude-l-draper-from-compulsory-retirement-for-age.json', 'input_tokens': 517, 'output_tokens': 115, 'duration': 1.2760443687438965}
# {'path': 'executive-order-10257-amendment-executive-order-7397-june-20-1936-amended-establishing-the.json', 'input_tokens': 680, 'output_tokens': 78, 'duration': 1.0877909660339355}
# {'path': 'executive-order-10256-amendment-paragraph-126e-the-manual-for-courts-martial-united-states.json', 'input_tokens': 522, 'output_tokens': 89, 'duration': 1.1243813037872314}
# {'path': 'executive-order-10253-providing-for-the-improvement-the-work-federal-executive-agencies.json', 'input_tokens': 1104, 'output_tokens': 136, 'duration': 1.7813150882720947}
# {'path': 'executive-order-10258-amending-the-selective-service-regulations.json', 'input_tokens': 1872, 'output_tokens': 90, 'duration': 1.1380021572113037}
# {'path': 'executive-order-10259-delegating-the-secretary-state-the-authority-vested-the-president.json', 'input_tokens': 414, 'output_tokens': 71, 'duration': 1.0432684421539307}
# {'path': 'executive-order-10260-designating-certain-agencies-pursuant-section-103-the-renenogiation.json', 'input_tokens': 519, 'output_tokens': 126, 'duration': 1.3839941024780273}
# {'path': 'executive-order-10263-transfer-the-panama-canal-the-waterway-together-with-facilities-and.json', 'input_tokens': 1577, 'output_tokens': 58, 'duration': 0.9093809127807617}
# {'path': 'executive-order-10265-transfer-the-administration-the-trust-territory-the-pacific-islands.json', 'input_tokens': 1122, 'output_tokens': 88, 'duration': 1.1139755249023438}
# {'path': 'executive-order-10261-amendment-executive-order-no-10000-september-16-1948-prescribing.json', 'input_tokens': 817, 'output_tokens': 125, 'duration': 1.717275619506836}
# {'path': 'executive-order-10264-transfer-the-administration-american-samoa-from-the-secretary-the.json', 'input_tokens': 871, 'output_tokens': 105, 'duration': 1.266625165939331}
# ...
# {'path': 'executive-order-jicarilla-apache-territory-restored-public-domain.json', 'input_tokens': 342, 'output_tokens': 84, 'duration': 1.2333061695098877}
# {'path': 'executive-order-keeping-education-accessible-and-ending-covid-19-vaccine-mandates-schools.json', 'input_tokens': 1187, 'output_tokens': 81, 'duration': 1.0646367073059082}
# {'path': 'executive-order-jicarilla-apache-indian-reservation-withdrawn.json', 'input_tokens': 448, 'output_tokens': 160, 'duration': 1.5811235904693604}
# {'path': 'executive-order-iowa-reserve-boundary.json', 'input_tokens': 420, 'output_tokens': 158, 'duration': 2.187281370162964}
# {'path': 'executive-order-license-commercial-intercourse.json', 'input_tokens': 523, 'output_tokens': 82, 'duration': 1.024930715560913}
# {'path': 'executive-order-little-traverse-reserve.json', 'input_tokens': 667, 'output_tokens': 92, 'duration': 1.1375608444213867}
# {'path': 'executive-order-making-henry-w-halleck-general-chief.json', 'input_tokens': 324, 'output_tokens': 74, 'duration': 0.9082169532775879}
# {'path': 'executive-order-land-for-jicarilla-apache-indians.json', 'input_tokens': 455, 'output_tokens': 149, 'duration': 1.6717588901519775}
# {'path': 'executive-order-making-america-healthy-again-empowering-patients-with-clear-accurate-and.json', 'input_tokens': 1256, 'output_tokens': 74, 'duration': 1.0574400424957275}
# {'path': 'executive-order-mandatory-retirement-age-for-officers-the-revenue-cutter-service.json', 'input_tokens': 346, 'output_tokens': 103, 'duration': 1.188389778137207}
# {'path': 'executive-order-modification-executive-order-may-21-1887.json', 'input_tokens': 723, 'output_tokens': 76, 'duration': 1.2190020084381104}
# {'path': 'executive-order-modification-white-mountain-indian-reservation-boundary-arizona-territory.json', 'input_tokens': 405, 'output_tokens': 88, 'duration': 1.1537063121795654}
# {'path': 'executive-order-modifying-and-reducing-the-reservation-port-point-and-point-jose-san.json', 'input_tokens': 560, 'output_tokens': 87, 'duration': 1.0249450206756592}
# {'path': 'executive-order-no-1-relating-political-prisoners.json', 'input_tokens': 1251, 'output_tokens': 97, 'duration': 1.1145367622375488}
# {'path': 'executive-order-new-mexico-mescalero-apaches-land.json', 'input_tokens': 601, 'output_tokens': 96, 'duration': 1.196000099182129}
# {'path': 'executive-order-navaho-reservation-utah.json', 'input_tokens': 417, 'output_tokens': 114, 'duration': 1.2762491703033447}
# {'path': 'executive-order-northern-cheyenne-reserve-0.json', 'input_tokens': 663, 'output_tokens': 143, 'duration': 1.3974378108978271}
# {'path': 'executive-order-nullifying-reservation-lands-michigan.json', 'input_tokens': 424, 'output_tokens': 73, 'duration': 0.9764537811279297}
# {'path': 'executive-order-no-2-state-prisoners.json', 'input_tokens': 458, 'output_tokens': 129, 'duration': 1.740161418914795}
# {'path': 'executive-order-northern-cheyenne-reserve-montana.json', 'input_tokens': 852, 'output_tokens': 103, 'duration': 1.574544906616211}
# {'path': 'executive-order-northern-cheyenne-reserve.json', 'input_tokens': 663, 'output_tokens': 143, 'duration': 1.4822521209716797}
# {'path': 'executive-order-ordering-the-arrest-and-designation-prisoners-war-all-persons-engaged.json', 'input_tokens': 528, 'output_tokens': 120, 'duration': 1.3517835140228271}
# {'path': 'executive-order-paroling-alexander-h-stephens-and-others.json', 'input_tokens': 536, 'output_tokens': 134, 'duration': 1.4156684875488281}
# {'path': 'executive-order-ordering-the-raising-the-flag-and-other-commemorations-fort-sumter.json', 'input_tokens': 535, 'output_tokens': 178, 'duration': 1.6275200843811035}
# {'path': 'executive-order-pima-and-maricopa-indian-reserve.json', 'input_tokens': 1110, 'output_tokens': 87, 'duration': 1.1051106452941895}
# {'path': 'executive-order-presidents-general-war-order-no-2.json', 'input_tokens': 575, 'output_tokens': 74, 'duration': 1.0245814323425293}
# {'path': 'executive-order-pine-ridge-school-reservation-south-dakota.json', 'input_tokens': 429, 'output_tokens': 102, 'duration': 1.2877163887023926}
# {'path': 'executive-order-presidents-general-war-order-no-3.json', 'input_tokens': 496, 'output_tokens': 146, 'duration': 1.3718254566192627}
# {'path': 'executive-order-pima-and-maricopa-or-gila-river-reserve.json', 'input_tokens': 519, 'output_tokens': 234, 'duration': 1.879964828491211}
# {'path': 'executive-order-reaffirmation-boundaries-for-the-colorado-river-indian-reservation.json', 'input_tokens': 582, 'output_tokens': 77, 'duration': 0.9865942001342773}
# {'path': 'executive-order-regarding-the-colonization-experiment.json', 'input_tokens': 444, 'output_tokens': 71, 'duration': 0.9193220138549805}
# {'path': 'executive-order-prohibiting-the-export-arms-and-munitions-war.json', 'input_tokens': 359, 'output_tokens': 79, 'duration': 1.4675028324127197}
# {'path': 'executive-order-presidents-special-war-order-no-3.json', 'input_tokens': 478, 'output_tokens': 195, 'duration': 1.6192572116851807}
# {'path': 'executive-order-reestablish-the-authority-the-united-states-and-execute-the-laws-within.json', 'input_tokens': 999, 'output_tokens': 116, 'duration': 1.3801727294921875}
# {'path': 'executive-order-regulations-for-the-distribution-arms-ordinance-stores-quartermasters.json', 'input_tokens': 520, 'output_tokens': 94, 'duration': 1.1920382976531982}
# {'path': 'executive-order-relieving-general-g-b-mcclellan-and-making-other-changes.json', 'input_tokens': 400, 'output_tokens': 80, 'duration': 1.186737060546875}
# {'path': 'executive-order-regard-behavior-aliens.json', 'input_tokens': 554, 'output_tokens': 151, 'duration': 1.9491524696350098}
# {'path': 'executive-order-rescinding-reservation-lands-for-mission-indians.json', 'input_tokens': 492, 'output_tokens': 74, 'duration': 0.9614567756652832}
# {'path': 'executive-order-rescinding-regulations-prohibiting-the-exportation-arms-ammunition-horses.json', 'input_tokens': 375, 'output_tokens': 98, 'duration': 1.1434714794158936}
# {'path': 'executive-order-reservation-for-boise-fort-band-chippewa-minnesota.json', 'input_tokens': 477, 'output_tokens': 100, 'duration': 1.3197581768035889}
# {'path': 'executive-order-reservation-for-mission-indians-california.json', 'input_tokens': 576, 'output_tokens': 85, 'duration': 1.3065717220306396}
# {'path': 'executive-order-removing-edwin-m-stanton-secretary-war.json', 'input_tokens': 399, 'output_tokens': 255, 'duration': 1.830064058303833}
# {'path': 'executive-order-reservation-land-for-indian-purposes-california.json', 'input_tokens': 355, 'output_tokens': 129, 'duration': 1.343437671661377}
# {'path': 'executive-order-reservation-land-for-pima-and-maricopa-indians-arizona.json', 'input_tokens': 746, 'output_tokens': 109, 'duration': 1.184540033340454}
# {'path': 'executive-order-reserving-from-sale-for-public-purposes-certain-lands-the-bay-san.json', 'input_tokens': 620, 'output_tokens': 67, 'duration': 0.947641134262085}
# {'path': 'executive-order-reservation-lands-california-for-indian-purposes.json', 'input_tokens': 413, 'output_tokens': 127, 'duration': 1.3491806983947754}
# {'path': 'executive-order-reservation-land-for-mission-indians-california.json', 'input_tokens': 394, 'output_tokens': 135, 'duration': 1.7009263038635254}
# {'path': 'executive-order-reserving-miraflores-island-puerto-rico.json', 'input_tokens': 385, 'output_tokens': 85, 'duration': 1.0517306327819824}
# {'path': 'executive-order-reserving-california-land-for-indian-purposes.json', 'input_tokens': 411, 'output_tokens': 156, 'duration': 1.6068663597106934}
# {'path': 'executive-order-reserving-land-for-pillager-and-lake-winnebagoshish-bands.json', 'input_tokens': 541, 'output_tokens': 122, 'duration': 1.3128440380096436}
# {'path': 'executive-order-restoration-lands-for-mission-indians.json', 'input_tokens': 384, 'output_tokens': 70, 'duration': 0.8450860977172852}
# {'path': 'executive-order-restoration-lands-public-domain.json', 'input_tokens': 664, 'output_tokens': 93, 'duration': 1.1724600791931152}
# {'path': 'executive-order-restoration-portion-tule-river-indian-reservation-public-domain.json', 'input_tokens': 479, 'output_tokens': 62, 'duration': 0.9711563587188721}
# {'path': 'executive-order-restoration-tract-montana-public-domain.json', 'input_tokens': 545, 'output_tokens': 99, 'duration': 1.1865732669830322}
# {'path': 'executive-order-restoring-portion-white-mountain-indian-reservation-public-domain.json', 'input_tokens': 324, 'output_tokens': 61, 'duration': 0.8208348751068115}
# {'path': 'executive-order-restoring-land-arizona-public-domain.json', 'input_tokens': 436, 'output_tokens': 67, 'duration': 1.1091656684875488}
# {'path': 'executive-order-restoring-tract-land-montana-territory-public-domain.json', 'input_tokens': 516, 'output_tokens': 59, 'duration': 0.9313318729400635}
# {'path': 'executive-order-restoring-chippewa-indian-land-public-domain.json', 'input_tokens': 461, 'output_tokens': 138, 'duration': 1.3948650360107422}
# {'path': 'executive-order-restoring-malheur-indian-reservation-public-domain.json', 'input_tokens': 570, 'output_tokens': 115, 'duration': 1.312927007675171}
# {'path': 'executive-order-retaliation.json', 'input_tokens': 508, 'output_tokens': 95, 'duration': 1.2131476402282715}
# {'path': 'executive-order-returning-sioux-land-dakota-public-domain.json', 'input_tokens': 899, 'output_tokens': 80, 'duration': 1.0290253162384033}
# {'path': 'executive-order-returning-niobrara-and-santee-sioux-land-public-domain.json', 'input_tokens': 429, 'output_tokens': 140, 'duration': 1.385122537612915}
# {'path': 'executive-order-revision-agua-caliente-and-santa-ysabel-indian-reservations.json', 'input_tokens': 625, 'output_tokens': 82, 'duration': 1.043447494506836}
# {'path': 'executive-order-revocation-chiricahua-reserve.json', 'input_tokens': 454, 'output_tokens': 57, 'duration': 0.9008862972259521}
# {'path': 'executive-order-returning-thanks-the-volunteers-for-one-hundred-days-from-the-states.json', 'input_tokens': 486, 'output_tokens': 160, 'duration': 1.2876315116882324}
# {'path': 'executive-order-revocation-camp-wright-military-reservation.json', 'input_tokens': 430, 'output_tokens': 92, 'duration': 1.0648174285888672}
# {'path': 'executive-order-revocation-executive-order-regarding-mission-indian-lands.json', 'input_tokens': 377, 'output_tokens': 64, 'duration': 0.9331779479980469}
# {'path': 'executive-order-returning-tulerosa-indian-land-public-domain.json', 'input_tokens': 371, 'output_tokens': 131, 'duration': 1.7680375576019287}
# {'path': 'executive-order-revocation-portion-white-mountain-indian-reservation.json', 'input_tokens': 401, 'output_tokens': 82, 'duration': 1.1204590797424316}
# {'path': 'executive-order-revoking-order-october-20-1875-establishing-crow-tribe-reservation-montana.json', 'input_tokens': 521, 'output_tokens': 63, 'duration': 0.8801825046539307}
# {'path': 'executive-order-revocation-portion-white-mountain-indian-reservation-0.json', 'input_tokens': 534, 'output_tokens': 106, 'duration': 1.245931625366211}
# {'path': 'executive-order-revocation-uncompahgre-park-portion.json', 'input_tokens': 463, 'output_tokens': 102, 'duration': 1.1706573963165283}
# {'path': 'executive-order-santa-clara-pueblo-new-mexico.json', 'input_tokens': 890, 'output_tokens': 89, 'duration': 1.0525341033935547}
# {'path': 'executive-order-setting-aside-certain-public-lands-for-use-connection-with-experimental.json', 'input_tokens': 343, 'output_tokens': 105, 'duration': 1.1793744564056396}
# {'path': 'executive-order-special-orders-216.json', 'input_tokens': 552, 'output_tokens': 64, 'duration': 1.1168887615203857}
# {'path': 'executive-order-special-orders-211.json', 'input_tokens': 683, 'output_tokens': 161, 'duration': 1.4054646492004395}
# {'path': 'executive-order-suspending-from-office-edwin-m-stanton-secretary-war.json', 'input_tokens': 378, 'output_tokens': 61, 'duration': 0.9248526096343994}
# {'path': 'executive-order-special-war-order-no-1.json', 'input_tokens': 353, 'output_tokens': 95, 'duration': 1.1244375705718994}
# {'path': 'executive-order-special-orders-219.json', 'input_tokens': 476, 'output_tokens': 64, 'duration': 1.168386459350586}
# {'path': 'executive-order-special-orders-503.json', 'input_tokens': 705, 'output_tokens': 90, 'duration': 1.3665556907653809}
# {'path': 'executive-order-suspension-the-writ-habeas-corpus.json', 'input_tokens': 346, 'output_tokens': 80, 'duration': 1.0728163719177246}
# {'path': 'executive-order-suppai-reserve.json', 'input_tokens': 535, 'output_tokens': 124, 'duration': 1.3362603187561035}
# {'path': 'executive-order-taking-military-possession-railroads.json', 'input_tokens': 365, 'output_tokens': 67, 'duration': 0.9894919395446777}
# {'path': 'executive-order-taking-into-military-possession-all-telegraph-lines-the-united-states.json', 'input_tokens': 484, 'output_tokens': 126, 'duration': 1.4193975925445557}
# {'path': 'executive-order-thanks-hundred-day-troops-from-ohio.json', 'input_tokens': 466, 'output_tokens': 104, 'duration': 1.2093846797943115}
# {'path': 'executive-order-tendering-thanks-admiral-farragut-and-major-general-canby.json', 'input_tokens': 395, 'output_tokens': 138, 'duration': 1.3391382694244385}
# {'path': 'executive-order-the-death-andrew-jackson.json', 'input_tokens': 1402, 'output_tokens': 97, 'duration': 1.0764386653900146}
# {'path': 'executive-order-the-civil-service-order.json', 'input_tokens': 474, 'output_tokens': 84, 'duration': 1.1863203048706055}
# {'path': 'executive-order-the-death-franklin-pierce.json', 'input_tokens': 653, 'output_tokens': 91, 'duration': 1.119304895401001}
# {'path': 'executive-order-tendering-thanks-major-general-william-t-sherman.json', 'input_tokens': 375, 'output_tokens': 138, 'duration': 1.4973907470703125}
# {'path': 'executive-order-the-death-james-k-polk.json', 'input_tokens': 853, 'output_tokens': 98, 'duration': 1.1014666557312012}
# {'path': 'executive-order-the-death-millard-fillmore.json', 'input_tokens': 890, 'output_tokens': 77, 'duration': 0.919621467590332}
# {'path': 'executive-order-the-death-martin-van-buren.json', 'input_tokens': 711, 'output_tokens': 99, 'duration': 1.1578242778778076}
# {'path': 'executive-order-uintah-valley-reserve.json', 'input_tokens': 464, 'output_tokens': 103, 'duration': 1.1830322742462158}
# {'path': 'executive-order-utah-and-arizona-land-public-domain.json', 'input_tokens': 403, 'output_tokens': 89, 'duration': 1.1493794918060303}
# {'path': 'executive-order-the-deaths-thomas-jefferson-and-john-adams.json', 'input_tokens': 1420, 'output_tokens': 107, 'duration': 1.296797275543213}
# {'path': 'executive-order-withdrawal-land-for-suppai-havasupai-indians.json', 'input_tokens': 487, 'output_tokens': 88, 'duration': 1.3004744052886963}
# {'path': 'executive-order-withdrawal-lands-from-sale-round-valley-indian-reservation-california.json', 'input_tokens': 349, 'output_tokens': 72, 'duration': 1.3069326877593994}
# {'path': 'executive-order-withdrawing-navajo-territories.json', 'input_tokens': 495, 'output_tokens': 79, 'duration': 0.9731106758117676}
# {'path': 'executive-order-withdrawn-navajo-lands.json', 'input_tokens': 397, 'output_tokens': 81, 'duration': 1.044459581375122}
# {'path': 'executive-order-withdrawing-sioux-indian-land.json', 'input_tokens': 394, 'output_tokens': 94, 'duration': 1.3854455947875977}
# {'path': 'executive-order.json', 'input_tokens': 867, 'output_tokens': 71, 'duration': 1.081331729888916}
# {'path': 'executive-order-yuma-reserve.json', 'input_tokens': 475, 'output_tokens': 94, 'duration': 1.1785523891448975}
# {'path': 'order-general-hw-halleck.json', 'input_tokens': 390, 'output_tokens': 72, 'duration': 0.9828410148620605}
# {'path': 'general-orders-no-20-relieving-general-ae-burnside-and-making-other-changes.json', 'input_tokens': 402, 'output_tokens': 128, 'duration': 1.378638505935669}
# {'path': 'order-constituting-the-army-virginia.json', 'input_tokens': 556, 'output_tokens': 112, 'duration': 1.4114859104156494}
# {'path': 'order-the-president-death-zachary-taylor.json', 'input_tokens': 338, 'output_tokens': 92, 'duration': 1.2775063514709473}

# %% [markdown]
# ## Political Bias

# %%
class PoliticalBias(BaseModel):
    ideological_tilt: int = Field(description="-5 = Highly Conservative, 0 = Centrist/Moderate, +5 = Highly Liberal")
    immigration: int = Field(description="-5 = Strictly Restrictive (Closed), 0 = Balanced/Selective, +5 = Extremely Open")
    executive_power: int = Field(description="-5 = Strongly Restrains Executive Authority, 0 = Neutral/Balanced, +5 = Strongly Expands Executive Authority")
    federalism: int = Field(description="-5 = Heavy State Control, 0 = Cooperative Balance, +5 = Strong Federal Control")
    security_liberty: int = Field(description="-5 = Strong Liberties/Privacy Focus, 0 = Balanced Approach, +5 = Heavy Security Focus")
    economic_regulation: int = Field(description="-5 = Strong Deregulation/Laissez-Faire, 0 = Moderate Regulation, +5 = Heavy Government Intervention")
    social_inclusion: int = Field(description="-5 = Emphasis on Conformity/Traditional Uniformity, 0 = Neutral, +5 = Emphasis on Diversity/Pluralism")

class PoliticalBiasResponse(BaseModel):
    initial_scores: PoliticalBias = Field(description="Initial political bias scores.")
    critique: str = Field(description="Critique of the initial scores.")
    revised_scores: PoliticalBias = Field(description="Revised political bias scores.")

political_bias_prompt = ChatPromptTemplate.from_template(
    '\n '.join([
        'Your task is assess the political bias and sentiment of each document, asses based on the following axes.',
        '# Ideological Tilt (Liberal vs. Conservative)', 
        '- Gauge where the document stands on the traditional left-right political spectrum (e.g., social welfare spending, cultural values, role of government).',
        '- -5 = Highly Conservative, 0 = Centrist/Moderate, +5 = Highly Liberal',
        '# Immigration Approach (Closed vs. Open Borders)',
        '- Reflects how permissive or restrictive the document is regarding immigration, visas, refugees, and border enforcement.',
        '- -5 = Strictly Restrictive (Closed), 0 = Balanced/Selective, +5 = Extremely Open',
        '# Executive Power (Restriction vs. Expansion)',
        '- Measures whether the document curtails presidential power (by imposing checks or limiting discretion) or broadens the executive\'s reach (allowing unilateral actions or emergency powers).',
        '- -5 = Strongly Restrains Executive Authority, 0 = Neutral/Balanced, +5 = Strongly Expands Executive Authority',
        '# Federalism (State vs. Federal Primacy)',
        '- Evaluates if the documents shifts power and decision-making downward to states or upward to the federal government. A high positive score suggests centralizing authority in Washington, while a negative score favors decentralized/state-led governance.',
        '- -5 = Heavy State Control, 0 = Cooperative Balance, +5 = Strong Federal Control',
        '# Security vs. Liberty (National Security vs. Civil Liberties)',
        '- Captures whether the document prioritizes national security and law enforcement powers (potentially at civil liberties\' expense) or emphasizes individual rights and freedoms (possibly limiting security measures).',
        '- -5 = Strong Liberties/Privacy Focus, 0 = Balanced Approach, +5 = Heavy Security Focus',
        '# Economic Regulation (Deregulation vs. Intervention)',
        '- Determines how deeply the document involves the government in economic matters—whether it rolls back rules and fosters free markets or imposes policies (e.g., wage/price controls, mandatory guidelines) to steer the economy.',
        '- -5 = Strong Deregulation/Laissez-Faire, 0 = Moderate Regulation, +5 = Heavy Government Intervention',
        '# Social Inclusion (Conformity vs. Diversity)',
        '- Assesses whether the document promotes inclusivity (racial, ethnic, religious, gender, LGBTQ+ protections) and encourages pluralism, or whether it trends toward uniform standards, fewer cultural accommodations, and more traditional/conforming policies.'
        '-5 = Emphasis on Conformity/Traditional Uniformity, 0 = Neutral, +5 = Emphasis on Diversity/Pluralism',
        '{text}',
    ])
)

def political_bias_pipeline(model):
    return political_bias_prompt | model.with_structured_output(PoliticalBiasResponse, include_raw=True)

# %%
source_dir = 'data/executive_orders/cleaned/'
target_dir = 'data/executive_orders/political_bias/'
log_path = 'data/executive_orders/political_bias_log.csv'

pipeline = political_bias_pipeline(gemini)

def process_eo(eo_path):
    stats = {
        'path': eo_path
    }

    start_time = time.time()
    try:
        with open(source_dir + eo_path) as source_file:
            eo = json.load(source_file)
            result = pipeline.invoke({'text': '\n'.join(eo["content"])})
            stats = stats | build_stats(result)

        # write the cleaned eo to the target directory
        with open(target_dir + eo_path, 'w') as target_file:
            json.dump(result['parsed'].model_dump(), target_file, indent=4)
    except Exception as e:
        stats['error'] = str(e)

    duration = time.time() - start_time
    stats['duration'] = duration

    return stats

# %%
concurrency = 8

eo_paths = os.listdir(source_dir)
eo_paths.sort()

results = []
with ThreadPoolExecutor(max_workers=concurrency) as executor:
    futures = [
        executor.submit(process_eo, path) for path in eo_paths[0:200]
    ]

    for future in as_completed(futures):
        result = future.result()
        print(result)
        results.append(result)

pandas.DataFrame(results).to_csv(log_path, index=False)
# Out:
# {'path': 'commission-appointing-commissioners-for-surveying-the-district-territory-for-the-permanent.json', 'input_tokens': 1057, 'output_tokens': 85, 'duration': 1.2045845985412598}
# {'path': 'executive-order-1.json', 'input_tokens': 802, 'output_tokens': 80, 'duration': 1.2111272811889648}
# {'path': 'executive-order-0.json', 'input_tokens': 802, 'output_tokens': 98, 'duration': 1.3281846046447754}
# {'path': 'executive-order-1000-alamo-national-forest-new-mexico.json', 'input_tokens': 1671, 'output_tokens': 84, 'duration': 1.352602481842041}
# {'path': 'executive-order-10.json', 'input_tokens': 844, 'output_tokens': 115, 'duration': 1.3770229816436768}
# {'path': 'executive-order-100.json', 'input_tokens': 1068, 'output_tokens': 90, 'duration': 1.4722206592559814}
# {'path': 'executive-order-10000-regulations-governing-additional-compensation-and-credit-granted.json', 'input_tokens': 5313, 'output_tokens': 105, 'duration': 1.4861409664154053}
# {'path': 'executive-order-10002-exemption-lawrence-m-lawson-from-compulsory-retirement-for-age.json', 'input_tokens': 761, 'output_tokens': 54, 'duration': 1.0208640098571777}
# {'path': 'executive-order-10004-prescribing-procedures-for-the-administration-the-reciprocal-trade.json', 'input_tokens': 3290, 'output_tokens': 102, 'duration': 1.2912261486053467}
# {'path': 'executive-order-10001-prescribing-or-amending-portions-the-selective-service-regulations.json', 'input_tokens': 21846, 'output_tokens': 162, 'duration': 2.6317079067230225}
# {'path': 'executive-order-10006-preparation-presentation-filing-and-publicaton-executive-orders-and.json', 'input_tokens': 1741, 'output_tokens': 93, 'duration': 1.3104703426361084}
# {'path': 'executive-order-10003-providing-for-the-investigation-and-report-displaced-persons-seeking.json', 'input_tokens': 971, 'output_tokens': 148, 'duration': 1.517956256866455}
# {'path': 'executive-order-10005-establishing-the-presidents-advisory-commission-the-relation-federal.json', 'input_tokens': 1202, 'output_tokens': 109, 'duration': 1.4082584381103516}
# {'path': 'executive-order-10007-organization-the-reserve-units-the-armed-forces.json', 'input_tokens': 1138, 'output_tokens': 116, 'duration': 1.5880072116851807}
# {'path': 'executive-order-10008-amending-the-selective-service-regulations.json', 'input_tokens': 7651, 'output_tokens': 137, 'duration': 1.6900749206542969}
# {'path': 'executive-order-10010-creating-emergency-board-investigate-disputes-between-the-akron.json', 'input_tokens': 2836, 'output_tokens': 109, 'duration': 1.2407121658325195}
# {'path': 'executive-order-10014-directing-federal-agencies-cooperate-with-sate-and-local-authorities.json', 'input_tokens': 975, 'output_tokens': 95, 'duration': 1.1939804553985596}
# {'path': 'executive-order-10013-establishing-the-presidents-committee-religious-and-moral-welfare.json', 'input_tokens': 1140, 'output_tokens': 89, 'duration': 1.2615199089050293}
# {'path': 'executive-order-10011-authorizing-the-secretary-state-exercise-certain-powers-the.json', 'input_tokens': 1757, 'output_tokens': 122, 'duration': 1.3771071434020996}
# {'path': 'executive-order-10009-revoking-part-executive-orders-no-589-march-14-1907-and-no-1712.json', 'input_tokens': 1257, 'output_tokens': 182, 'duration': 1.8519504070281982}
# {'path': 'executive-order-10012-excluding-from-the-provisions-the-classification-act-1923-amended.json', 'input_tokens': 1018, 'output_tokens': 101, 'duration': 1.4114770889282227}
# {'path': 'executive-order-10016-coat-arms-seal-and-flag-the-vice-president-the-united-states.json', 'input_tokens': 1272, 'output_tokens': 96, 'duration': 1.1753137111663818}
# {'path': 'executive-order-10015-amendment-executive-order-no-10010-creating-emergency-board.json', 'input_tokens': 1031, 'output_tokens': 107, 'duration': 1.3653302192687988}
# {'path': 'executive-order-10019-excusing-federal-employees-from-duty-one-half-day-december-24-1948.json', 'input_tokens': 964, 'output_tokens': 95, 'duration': 1.200024127960205}
# {'path': 'executive-order-10021-further-exemption-harry-b-mitchell-from-compulsory-retirement-for.json', 'input_tokens': 939, 'output_tokens': 80, 'duration': 1.1597185134887695}
# {'path': 'executive-order-10022-transferring-the-use-possession-and-control-certain-lands-from-the.json', 'input_tokens': 1111, 'output_tokens': 97, 'duration': 1.2190723419189453}
# {'path': 'executive-order-10017-amendment-the-regulations-governing-the-appointment-postmasters-the.json', 'input_tokens': 1015, 'output_tokens': 129, 'duration': 1.4652040004730225}
# {'path': 'executive-order-10018-transferring-the-control-and-jurisdiction-over-certain-tracts-land.json', 'input_tokens': 2399, 'output_tokens': 126, 'duration': 1.4339194297790527}
# {'path': 'executive-order-10020-prescribing-the-manual-for-courts-martial-us-army-1949.json', 'input_tokens': 1162, 'output_tokens': 138, 'duration': 1.6356697082519531}
# {'path': 'executive-order-10024-restoration-lands-location-and-entry-under-the-mining-laws-the.json', 'input_tokens': 977, 'output_tokens': 103, 'duration': 1.4203989505767822}
# {'path': 'executive-order-10023-amendment-executive-order-9984-july-31-1948-prescribing-regulations.json', 'input_tokens': 1262, 'output_tokens': 141, 'duration': 1.8729915618896484}
# {'path': 'executive-order-10026-korea.json', 'input_tokens': 754, 'output_tokens': 53, 'duration': 0.9864366054534912}
# {'path': 'executive-order-10025-designating-public-international-organizations-entitled-enjoy.json', 'input_tokens': 1074, 'output_tokens': 98, 'duration': 1.1604464054107666}
# {'path': 'executive-order-10027-extension-trust-periods-indian-lands-expiring-during-the-calendar.json', 'input_tokens': 1013, 'output_tokens': 106, 'duration': 1.3964099884033203}
# {'path': 'executive-order-10029-creating-emergency-board-investigate-dispute-between-the-northwest.json', 'input_tokens': 1044, 'output_tokens': 92, 'duration': 1.1404566764831543}
# {'path': 'executive-order-10030-administration-and-supervision-the-district-columbia-national-guard.json', 'input_tokens': 1013, 'output_tokens': 122, 'duration': 1.2476906776428223}
# {'path': 'executive-order-10026-adopting-the-manual-for-courts-martial-us-army-1949-for-use-the.json', 'input_tokens': 3089, 'output_tokens': 176, 'duration': 2.0131947994232178}
# {'path': 'executive-order-10028-defining-noncombatant-service-and-noncombatant-training.json', 'input_tokens': 968, 'output_tokens': 151, 'duration': 1.9296386241912842}
# {'path': 'executive-order-10031-separation-officers-the-public-health-service-grounds-disloyalty.json', 'input_tokens': 1158, 'output_tokens': 87, 'duration': 1.322760820388794}
# {'path': 'executive-order-10032-creating-emergency-board-investigate-dispute-between-the-akron.json', 'input_tokens': 1752, 'output_tokens': 101, 'duration': 1.3753530979156494}
# {'path': 'executive-order-10034-further-exemption-john-monroe-johnson-from-compulsory-retirement-for.json', 'input_tokens': 988, 'output_tokens': 93, 'duration': 1.2374658584594727}
# {'path': 'executive-order-10033-regulations-governing-the-providing-statistical-information.json', 'input_tokens': 1610, 'output_tokens': 111, 'duration': 1.6696171760559082}
# {'path': 'executive-order-10035-designating-the-honorable-luis-negron-fernandez-acting-judge-the.json', 'input_tokens': 951, 'output_tokens': 97, 'duration': 1.3250741958618164}
# {'path': 'executive-order-10036-restoration-lands-location-and-entry-under-the-mining-laws-the.json', 'input_tokens': 1010, 'output_tokens': 103, 'duration': 1.1617660522460938}
# {'path': 'executive-order-10038-creating-emergency-board-investigate-dispute-between-the-carriers.json', 'input_tokens': 1072, 'output_tokens': 91, 'duration': 1.209155797958374}
# {'path': 'executive-order-10037-creating-emergency-board-investigate-dispute-between-the-denver-rio.json', 'input_tokens': 1054, 'output_tokens': 110, 'duration': 1.6255667209625244}
# {'path': 'executive-order-10039-authorizing-the-civil-service-commission-confer-competitive-status.json', 'input_tokens': 984, 'output_tokens': 110, 'duration': 1.4420900344848633}
# {'path': 'executive-order-10040-amendment-executive-order-no-9999-suspending-certain-statutory.json', 'input_tokens': 1075, 'output_tokens': 117, 'duration': 1.4768712520599365}
# {'path': 'executive-order-10041-restoring-certain-lands-the-united-states-naval-reservation-hanapepe.json', 'input_tokens': 1300, 'output_tokens': 96, 'duration': 1.2406196594238281}
# {'path': 'executive-order-10043-changing-the-name-the-presidents-committee-religious-and-moral.json', 'input_tokens': 877, 'output_tokens': 100, 'duration': 1.2904720306396484}
# {'path': 'executive-order-10042-making-certain-changes-the-customs-field-organization.json', 'input_tokens': 1278, 'output_tokens': 138, 'duration': 1.5601389408111572}
# {'path': 'executive-order-10044-amendment-executive-order-no-9-january-17-1873-relating-the-holding.json', 'input_tokens': 977, 'output_tokens': 114, 'duration': 1.7166640758514404}
# {'path': 'executive-order-10045-creating-emergency-board-investigate-dispute-between-the-wabash.json', 'input_tokens': 1068, 'output_tokens': 123, 'duration': 1.5430381298065186}
# {'path': 'executive-order-10047-restoring-portion-honolulu-harbor-the-jurisdicton-the-territory.json', 'input_tokens': 1623, 'output_tokens': 105, 'duration': 1.2496788501739502}
# {'path': 'executive-order-10046-transferring-certain-lands-from-the-department-agriculture-the.json', 'input_tokens': 12055, 'output_tokens': 101, 'duration': 1.3731694221496582}
# {'path': 'executive-order-10048-creating-emergency-board-investigate-dispute-between-the-southern.json', 'input_tokens': 1052, 'output_tokens': 105, 'duration': 1.3508894443511963}
# {'path': 'executive-order-10049-delegating-the-authority-the-president-prescribe-clothing-allowances.json', 'input_tokens': 1074, 'output_tokens': 101, 'duration': 1.3164565563201904}
# {'path': 'executive-order-10051-creating-emergency-board-investigate-dispute-between-the-aliquippa.json', 'input_tokens': 1055, 'output_tokens': 91, 'duration': 1.3409035205841064}
# {'path': 'executive-order-10050-creating-emergency-board-investigate-dispute-between-the-railway.json', 'input_tokens': 1053, 'output_tokens': 140, 'duration': 1.874920129776001}
# {'path': 'executive-order-10055-amendment-executive-order-no-9-january-17-1873-relating-the-holding.json', 'input_tokens': 1164, 'output_tokens': 88, 'duration': 1.1844916343688965}
# {'path': 'executive-order-10052-enlarging-naval-petroleum-reserve-no-1-revoking-part-public-land.json', 'input_tokens': 1139, 'output_tokens': 121, 'duration': 1.5904271602630615}
# {'path': 'executive-order-10054-modifying-executive-order-no-9721-providing-for-the-transfer.json', 'input_tokens': 990, 'output_tokens': 140, 'duration': 1.3441705703735352}
# {'path': 'executive-order-10053-regulations-governing-the-transportation-household-goods-members-the.json', 'input_tokens': 18780, 'output_tokens': 128, 'duration': 1.662506341934204}
# {'path': 'executive-order-10057-transferring-the-american-battle-monuments-commission-functions.json', 'input_tokens': 1385, 'output_tokens': 97, 'duration': 1.3973145484924316}
# {'path': 'executive-order-10056-creating-emergency-board-investigate-dispute-between-the-union.json', 'input_tokens': 1052, 'output_tokens': 135, 'duration': 1.570847749710083}
# {'path': 'executive-order-10058-restoring-certain-lands-keaukaha-waiakea-south-hilo-hawaii-the.json', 'input_tokens': 1364, 'output_tokens': 103, 'duration': 1.2873916625976562}
# {'path': 'executive-order-10061-amendment-executive-order-no-9871-amended-prescribing-regulations.json', 'input_tokens': 1371, 'output_tokens': 80, 'duration': 1.2125909328460693}
# {'path': 'executive-order-10060-restoring-certain-land-comprising-the-keaahala-military-reservation.json', 'input_tokens': 1075, 'output_tokens': 101, 'duration': 1.407257080078125}
# {'path': 'executive-order-10059-amendment-executive-order-no-9195-july-7-1942-amended-prescribing.json', 'input_tokens': 1459, 'output_tokens': 139, 'duration': 1.6702806949615479}
# {'path': 'executive-order-10062-establishing-the-position-united-states-high-commissioner-for.json', 'input_tokens': 1230, 'output_tokens': 124, 'duration': 1.4260542392730713}
# {'path': 'executive-order-10063-defining-certain-functions-the-united-states-high-commissioner-for.json', 'input_tokens': 980, 'output_tokens': 111, 'duration': 1.3191330432891846}
# {'path': 'executive-order-10064-further-extension-executive-order-no-9898-october-14-1947-amended.json', 'input_tokens': 1223, 'output_tokens': 116, 'duration': 1.2332987785339355}
# {'path': 'executive-order-10065-termination-the-office-defense-transportation.json', 'input_tokens': 1209, 'output_tokens': 102, 'duration': 1.3610665798187256}
# {'path': 'executive-order-10066-including-certain-lands-the-cherokee-national-forest.json', 'input_tokens': 1231, 'output_tokens': 103, 'duration': 1.6030960083007812}
# {'path': 'executive-order-10069-amendment-executive-order-no-9805-prescribing-regulaitons-governing.json', 'input_tokens': 1346, 'output_tokens': 85, 'duration': 1.1513290405273438}
# {'path': 'executive-order-10068-revoking-order-no-2458-or-september-20-1916-establishing-inter.json', 'input_tokens': 836, 'output_tokens': 112, 'duration': 1.2847671508789062}
# {'path': 'executive-order-10067-creating-emergency-board-investigate-dispute-between-the-missouri.json', 'input_tokens': 1069, 'output_tokens': 115, 'duration': 1.392493486404419}
# {'path': 'executive-order-10070-amending-executive-order-no-9975-july-7-1948-prescribing-regulations.json', 'input_tokens': 1064, 'output_tokens': 120, 'duration': 1.2719752788543701}
# {'path': 'executive-order-10071-creating-emergency-board-investigate-dispute-between-the-southern.json', 'input_tokens': 1047, 'output_tokens': 92, 'duration': 1.3077418804168701}
# {'path': 'executive-order-10072-provide-for-continuing-action-improve-the-management-the-executive.json', 'input_tokens': 1240, 'output_tokens': 130, 'duration': 1.4337751865386963}
# {'path': 'executive-order-10073-exemption-eugene-black-from-compulsory-retirement-for-age.json', 'input_tokens': 951, 'output_tokens': 105, 'duration': 1.2098817825317383}
# {'path': 'executive-order-10074-transfer-the-district-land-office-carson-city-nevada-reno-nevada.json', 'input_tokens': 910, 'output_tokens': 78, 'duration': 1.2114713191986084}
# {'path': 'executive-order-10078-creating-emergency-board-investigate-dispute-between-the-monongahela.json', 'input_tokens': 1072, 'output_tokens': 87, 'duration': 1.0660686492919922}
# {'path': 'executive-order-10077-transfer-the-administration-the-island-guam-from-the-secretary-the.json', 'input_tokens': 1253, 'output_tokens': 92, 'duration': 1.3367094993591309}
# {'path': 'executive-order-10079-transferring-certain-property-the-virgin-islands-the-permanent.json', 'input_tokens': 1103, 'output_tokens': 101, 'duration': 1.2420878410339355}
# {'path': 'executive-order-10076-inspection-income-excess-profits-and-declared-value-excess-profits.json', 'input_tokens': 963, 'output_tokens': 101, 'duration': 1.6467394828796387}
# {'path': 'executive-order-10080-enabling-certain-employees-the-federal-government-acquire.json', 'input_tokens': 1147, 'output_tokens': 133, 'duration': 1.2892181873321533}
# {'path': 'executive-order-10081-designation-certain-officers-act-postmaster-general.json', 'input_tokens': 948, 'output_tokens': 113, 'duration': 1.3456518650054932}
# {'path': 'executive-order-10075-eliminating-certain-public-lands-from-naval-petroleum-reserve-no-2.json', 'input_tokens': 1342, 'output_tokens': 141, 'duration': 2.0800862312316895}
# {'path': 'executive-order-10082-prescribing-procedures-for-the-administration-the-reciprocal-trade.json', 'input_tokens': 3123, 'output_tokens': 118, 'duration': 1.402193546295166}
# {'path': 'executive-order-10083-revocation-executive-orders-nos-9698-9751-and-9823-so-far-they.json', 'input_tokens': 1005, 'output_tokens': 113, 'duration': 1.3089489936828613}
# {'path': 'executive-order-10086-designating-the-south-pacific-commission-public-international.json', 'input_tokens': 943, 'output_tokens': 82, 'duration': 1.121563196182251}
# {'path': 'executive-order-10085-amendment-executive-order-no-10011-authorizing-the-secretary-state.json', 'input_tokens': 1062, 'output_tokens': 117, 'duration': 1.423905372619629}
# {'path': 'executive-order-10084-prescribing-regulations-for-the-administration-certain-provisions.json', 'input_tokens': 950, 'output_tokens': 138, 'duration': 1.706679105758667}
# {'path': 'executive-order-10088-making-certain-changes-the-customs-field-organization.json', 'input_tokens': 1013, 'output_tokens': 103, 'duration': 1.233114242553711}
# {'path': 'executive-order-10090-inspection-income-tax-returns-federal-trade-commission.json', 'input_tokens': 1022, 'output_tokens': 78, 'duration': 0.984870433807373}
# {'path': 'executive-order-10087-amendment-executive-order-no-10057-may-14-1949-transferring-the.json', 'input_tokens': 1396, 'output_tokens': 134, 'duration': 1.7005589008331299}
# {'path': 'executive-order-10089-suspending-certain-statutory-provisions-relating-employment-the.json', 'input_tokens': 972, 'output_tokens': 115, 'duration': 1.3984484672546387}
# {'path': 'executive-order-10091-extension-trust-periods-indian-lands-expiring-during-the-calendar.json', 'input_tokens': 996, 'output_tokens': 97, 'duration': 1.3101754188537598}
# {'path': 'executive-order-10093-revocation-executive-order-no-9512-january-16-1945-providing-for.json', 'input_tokens': 837, 'output_tokens': 119, 'duration': 1.2559497356414795}
# {'path': 'executive-order-10092-establishing-airspace-reservation-over-certain-areas-the-superior.json', 'input_tokens': 3996, 'output_tokens': 128, 'duration': 1.5228052139282227}
# {'path': 'executive-order-10095-establishment-the-presidents-water-resources-policy-commission.json', 'input_tokens': 1383, 'output_tokens': 97, 'duration': 1.2674176692962646}
# {'path': 'executive-order-10094-further-exemption-clyde-b-aitchison-from-compulsory-retirement-for.json', 'input_tokens': 1030, 'output_tokens': 111, 'duration': 1.3271613121032715}
# {'path': 'executive-order-10097-designating-the-honorable-cecil-snyder-acting-judge-the-united.json', 'input_tokens': 967, 'output_tokens': 77, 'duration': 1.1180520057678223}
# {'path': 'executive-order-10096-providing-for-uniform-patent-policy-for-the-government-with-respect.json', 'input_tokens': 2874, 'output_tokens': 109, 'duration': 1.278609037399292}
# {'path': 'executive-order-10098-amendment-executive-order-no-10084-october-12-1949-prescribing.json', 'input_tokens': 923, 'output_tokens': 115, 'duration': 1.4396491050720215}
# {'path': 'executive-order-101.json', 'input_tokens': 904, 'output_tokens': 118, 'duration': 1.3950841426849365}
# {'path': 'executive-order-10101-amendment-executive-order-no-9746-july-1-1946-relating-the-panama.json', 'input_tokens': 1206, 'output_tokens': 97, 'duration': 1.220106601715088}
# {'path': 'executive-order-10099-providing-for-the-administration-the-mutual-defense-assistance-act.json', 'input_tokens': 1320, 'output_tokens': 132, 'duration': 1.771902322769165}
# {'path': 'executive-order-10102-transfer-certain-business-operations-facilities-and-appurtenances.json', 'input_tokens': 1963, 'output_tokens': 131, 'duration': 1.2988951206207275}
# {'path': 'executive-order-10100-regulations-relating-the-granting-certain-allowances-the-director.json', 'input_tokens': 1056, 'output_tokens': 99, 'duration': 1.4895119667053223}
# {'path': 'executive-order-10103-amendment-executive-order-no-9721-may-10-1946-providing-for-the.json', 'input_tokens': 1300, 'output_tokens': 112, 'duration': 1.2713470458984375}
# {'path': 'executive-order-10104-defining-certain-vital-military-and-naval-installations-and.json', 'input_tokens': 1852, 'output_tokens': 95, 'duration': 1.3233380317687988}
# {'path': 'executive-order-10105-creating-emergency-board-investigate-dispute-between-the-denver-and.json', 'input_tokens': 1047, 'output_tokens': 89, 'duration': 1.3792200088500977}
# {'path': 'executive-order-10107-revocation-executive-order-no-8232-september-5-1939-relating-the.json', 'input_tokens': 860, 'output_tokens': 91, 'duration': 1.1092665195465088}
# {'path': 'executive-order-10106-creating-board-inquiry-report-labor-dispute-affecting-the-bituminous.json', 'input_tokens': 1051, 'output_tokens': 107, 'duration': 1.2245876789093018}
# {'path': 'executive-order-10109-creating-emergency-board-investigate-disputes-between-the-texas.json', 'input_tokens': 1114, 'output_tokens': 96, 'duration': 1.1635432243347168}
# {'path': 'executive-order-10110-presidents-communications-policy-board.json', 'input_tokens': 1327, 'output_tokens': 91, 'duration': 1.1165003776550293}
# {'path': 'executive-order-10111-establishing-seal-for-the-central-intelligence-agency.json', 'input_tokens': 1072, 'output_tokens': 79, 'duration': 1.191657543182373}
# {'path': 'executive-order-10108-designating-the-united-states-mission-the-united-nations-and.json', 'input_tokens': 1339, 'output_tokens': 159, 'duration': 1.7067983150482178}
# {'path': 'executive-order-10113-delegating-the-authority-the-president-prescribe-clothing-allowances.json', 'input_tokens': 1261, 'output_tokens': 87, 'duration': 1.2234447002410889}
# {'path': 'executive-order-10112-creating-emergency-board-investigate-dispute-betweent-the-carriers.json', 'input_tokens': 1083, 'output_tokens': 133, 'duration': 1.7222421169281006}
# {'path': 'executive-order-10115-restoring-certain-land-reserved-for-military-purposes-the.json', 'input_tokens': 1595, 'output_tokens': 102, 'duration': 1.1888396739959717}
# {'path': 'executive-order-10114-creating-emergency-board-investigate-dispute-between-the-terminal.json', 'input_tokens': 1056, 'output_tokens': 107, 'duration': 1.5381712913513184}
# {'path': 'executive-order-10117-creating-emergency-board-investigate-dispute-between-the-carriers.json', 'input_tokens': 1046, 'output_tokens': 107, 'duration': 1.3784136772155762}
# {'path': 'executive-order-10118-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 1033, 'output_tokens': 115, 'duration': 1.3245620727539062}
# {'path': 'executive-order-10116-amending-portions-the-selective-service-regulations-and-paragraph-2.json', 'input_tokens': 4662, 'output_tokens': 104, 'duration': 1.4911456108093262}
# {'path': 'executive-order-10120-creating-emergency-board-investigate-dispute-between-the-carriers.json', 'input_tokens': 1077, 'output_tokens': 105, 'duration': 1.1279313564300537}
# {'path': 'executive-order-10119-regulations-governing-the-payment-basic-allowances-for-subsistence.json', 'input_tokens': 1667, 'output_tokens': 105, 'duration': 1.3008551597595215}
# {'path': 'executive-order-10121-transferring-the-territory-hawaii-title-certain-public-land-needed.json', 'input_tokens': 5075, 'output_tokens': 129, 'duration': 1.4304053783416748}
# {'path': 'executive-order-10122-regulations-governing-payment-disability-retirement-pay.json', 'input_tokens': 2015, 'output_tokens': 109, 'duration': 1.2931289672851562}
# {'path': 'executive-order-10123-revocation-executive-order-no-9635-september-29-1945-and-no-9904.json', 'input_tokens': 962, 'output_tokens': 111, 'duration': 1.2093188762664795}
# {'path': 'executive-order-10126-establishing-airspace-reservation-over-portions-the-district.json', 'input_tokens': 1352, 'output_tokens': 97, 'duration': 1.12959885597229}
# {'path': 'executive-order-10125-creating-emergency-board-investigate-dispute-between-the-chicago.json', 'input_tokens': 1047, 'output_tokens': 74, 'duration': 1.1626427173614502}
# {'path': 'executive-order-10124-regulations-governing-the-election-certain-members-and-former.json', 'input_tokens': 1399, 'output_tokens': 107, 'duration': 1.4219377040863037}
# {'path': 'executive-order-10128-amendment-executive-order-no-6868-october-9-1934-amended-designating.json', 'input_tokens': 965, 'output_tokens': 77, 'duration': 1.1833600997924805}
# {'path': 'executive-order-10127-establishing-airspace-reservations-over-certain-facilities-the.json', 'input_tokens': 1540, 'output_tokens': 79, 'duration': 1.1977014541625977}
# {'path': 'executive-order-10129-establishing-the-presidents-commission-migratory-labor.json', 'input_tokens': 1454, 'output_tokens': 104, 'duration': 1.2377159595489502}
# {'path': 'executive-order-10130-creating-emergency-board-investigate-dispute-between-the-boston.json', 'input_tokens': 1055, 'output_tokens': 117, 'duration': 1.4102239608764648}
# {'path': 'executive-order-10131-providing-for-the-investigation-and-report-displaced-pesons-and.json', 'input_tokens': 1083, 'output_tokens': 100, 'duration': 1.253408670425415}
# {'path': 'executive-order-10133-designating-the-organization-for-european-economic-cooperation.json', 'input_tokens': 893, 'output_tokens': 87, 'duration': 1.2596509456634521}
# {'path': 'executive-order-10132-inspection-income-excess-profits-declared-value-excess-profits.json', 'input_tokens': 1009, 'output_tokens': 124, 'duration': 1.2982714176177979}
# {'path': 'executive-order-10134-further-extension-the-existence-the-quetico-superior-committee.json', 'input_tokens': 936, 'output_tokens': 96, 'duration': 1.1532518863677979}
# {'path': 'executive-order-10135-further-extension-executive-order-no-9898-october-14-1947-amended.json', 'input_tokens': 1247, 'output_tokens': 144, 'duration': 1.5186572074890137}
# {'path': 'executive-order-10136-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 1068, 'output_tokens': 120, 'duration': 1.5319135189056396}
# {'path': 'executive-order-10137-amending-executive-order-no-10077-september-7-1949-entitled-transfer.json', 'input_tokens': 923, 'output_tokens': 119, 'duration': 1.6766901016235352}
# {'path': 'executive-order-10139-creating-emergency-board-investigate-dispute-between-the-toledo.json', 'input_tokens': 1058, 'output_tokens': 100, 'duration': 1.3109664916992188}
# {'path': 'executive-order-10138-creating-emergency-board-investigate-dispute-between-the-toledo.json', 'input_tokens': 1060, 'output_tokens': 113, 'duration': 1.3760404586791992}
# {'path': 'executive-order-10140-creating-emergency-board-investigate-dispute-between-the-pullman.json', 'input_tokens': 1034, 'output_tokens': 110, 'duration': 1.2938814163208008}
# {'path': 'executive-order-10142-creating-emergency-board-investigate-dispute-between-the-braniff.json', 'input_tokens': 1056, 'output_tokens': 114, 'duration': 1.4536290168762207}
# {'path': 'executive-order-10141-possession-control-and-operation-the-transportation-system-the.json', 'input_tokens': 2001, 'output_tokens': 136, 'duration': 1.5913782119750977}
# {'path': 'executive-order-10143-authorizing-the-appointment-mrs-ruth-edna-mcc-somers-position-the.json', 'input_tokens': 889, 'output_tokens': 94, 'duration': 1.3950567245483398}
# {'path': 'executive-order-10144-amendment-executive-order-no-10062-june-6-1949-establishing-the.json', 'input_tokens': 1046, 'output_tokens': 86, 'duration': 1.4618566036224365}
# {'path': 'executive-order-10145-extension-enlistements-the-armed-forces-the-united-states.json', 'input_tokens': 976, 'output_tokens': 103, 'duration': 1.2111468315124512}
# {'path': 'executive-order-10146-exemption-william-j-pattersn-from-compulsory-retirement-for-age.json', 'input_tokens': 983, 'output_tokens': 97, 'duration': 1.269906759262085}
# {'path': 'executive-order-10147-creating-emergency-board-investigate-dispute-between-the-new-york.json', 'input_tokens': 1077, 'output_tokens': 96, 'duration': 1.2870144844055176}
# {'path': 'executive-order-10148-designation-certain-officers-the-department-commerce-act-secretary.json', 'input_tokens': 1031, 'output_tokens': 110, 'duration': 1.324129343032837}
# {'path': 'executive-order-10149-suspending-the-limitations-upon-punishments-for-violations-articles.json', 'input_tokens': 1043, 'output_tokens': 103, 'duration': 1.2924003601074219}
# {'path': 'executive-order-10150-creating-emergency-board-investigate-disputes-between-the-atlantic.json', 'input_tokens': 1473, 'output_tokens': 114, 'duration': 1.2198679447174072}
# {'path': 'executive-order-10151-exemption-william-d-hassett-from-compulsory-retirement-for-age.json', 'input_tokens': 947, 'output_tokens': 103, 'duration': 1.211031436920166}
# {'path': 'executive-order-10152-regulations-relating-the-right-members-the-uniformed-services.json', 'input_tokens': 3155, 'output_tokens': 108, 'duration': 1.2045173645019531}
# {'path': 'executive-order-10153-regulations-relating-certain-travel-time-members-the-uniformed.json', 'input_tokens': 1202, 'output_tokens': 94, 'duration': 1.207587480545044}
# {'path': 'executive-order-10154-designation-certain-officers-the-post-office-department-act.json', 'input_tokens': 937, 'output_tokens': 99, 'duration': 1.1564984321594238}
# {'path': 'executive-order-10156-designation-certain-officers-the-department-the-interior-act.json', 'input_tokens': 1066, 'output_tokens': 110, 'duration': 1.262993574142456}
# {'path': 'executive-order-10155-possession-control-and-operation-certain-railroads.json', 'input_tokens': 5886, 'output_tokens': 133, 'duration': 1.5230014324188232}
# {'path': 'executive-order-10158-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 1018, 'output_tokens': 114, 'duration': 1.3737268447875977}
# {'path': 'executive-order-10157-enabling-certain-employees-the-federal-government-acquire.json', 'input_tokens': 1248, 'output_tokens': 139, 'duration': 1.449341058731079}
# {'path': 'executive-order-10159-providing-for-the-administration-the-act-for-international.json', 'input_tokens': 1146, 'output_tokens': 96, 'duration': 1.3682835102081299}
# {'path': 'executive-order-10160-providing-for-the-preservation-records-for-certain-purposes-the.json', 'input_tokens': 1330, 'output_tokens': 127, 'duration': 1.4962995052337646}
# {'path': 'executive-order-10162-authorizing-the-appointment-frederick-c-kilguss-the-position-deputy.json', 'input_tokens': 868, 'output_tokens': 79, 'duration': 1.339479684829712}
# {'path': 'executive-order-10163-the-armed-forces-reserve-medal.json', 'input_tokens': 1392, 'output_tokens': 98, 'duration': 1.2288575172424316}
# {'path': 'executive-order-10164-extension-enlistments-the-united-states-coast-guard.json', 'input_tokens': 1006, 'output_tokens': 77, 'duration': 1.1037137508392334}
# {'path': 'executive-order-10161-delegating-certain-functions-the-president-under-the-defense.json', 'input_tokens': 5853, 'output_tokens': 98, 'duration': 1.6802663803100586}
# {'path': 'executive-order-10165-creating-emergency-board-investigate-dispute-between-the-railway.json', 'input_tokens': 1073, 'output_tokens': 83, 'duration': 1.1047050952911377}
# {'path': 'executive-order-10166-establishing-the-national-advisory-committee-the-selection-doctors.json', 'input_tokens': 1315, 'output_tokens': 110, 'duration': 1.314831256866455}
# {'path': 'executive-order-10168-regulations-relating-the-right-enlisted-members-the-uniformed.json', 'input_tokens': 1849, 'output_tokens': 119, 'duration': 1.2159030437469482}
# {'path': 'executive-order-10169-establishing-the-national-advisory-committee-mobilization-policy.json', 'input_tokens': 1023, 'output_tokens': 82, 'duration': 1.1060981750488281}
# {'path': 'executive-order-10170-amendment-executive-order-no-10082-october-5-1949-prescribing.json', 'input_tokens': 1070, 'output_tokens': 75, 'duration': 1.0476367473602295}
# {'path': 'executive-order-10172-designating-the-certifying-authority-with-respect-the-amortization.json', 'input_tokens': 983, 'output_tokens': 99, 'duration': 1.1518783569335938}
# {'path': 'executive-order-10171-transferring-occupation-functions-austria-the-department-state.json', 'input_tokens': 1302, 'output_tokens': 119, 'duration': 1.3605427742004395}
# {'path': 'executive-order-10167-prescribing-or-amending-portions-the-selective-service-regulations.json', 'input_tokens': 6953, 'output_tokens': 145, 'duration': 2.1445024013519287}
# {'path': 'executive-order-10173-regulations-relating-the-safeguarding-vessels-harbors-ports-and.json', 'input_tokens': 3493, 'output_tokens': 141, 'duration': 1.647627830505371}
# {'path': 'executive-order-10177-amendment-section-1-executive-order-no-9778-september-10-1946.json', 'input_tokens': 1182, 'output_tokens': 89, 'duration': 1.2573738098144531}
# {'path': 'executive-order-10174-further-amendment-executive-order-no-10084-october-12-1949.json', 'input_tokens': 1032, 'output_tokens': 163, 'duration': 1.869384765625}
# {'path': 'executive-order-10176-suspending-certain-statutory-provisions-relating-employment-the.json', 'input_tokens': 951, 'output_tokens': 101, 'duration': 1.4321794509887695}
# {'path': 'executive-order-10175-amending-executive-order-no-7908-june-9-1938-and-executive-order-no.json', 'input_tokens': 1345, 'output_tokens': 118, 'duration': 1.722435712814331}
# {'path': 'executive-order-10180-establishing-special-personnel-procedures-the-interest-the-national.json', 'input_tokens': 1590, 'output_tokens': 92, 'duration': 1.2052056789398193}
# {'path': 'executive-order-10178-reserving-certain-real-and-personal-property-guam-for-the-use-the.json', 'input_tokens': 2094, 'output_tokens': 130, 'duration': 1.4849600791931152}
# {'path': 'executive-order-10181-delegating-the-director-the-bureau-the-budget-the-function.json', 'input_tokens': 876, 'output_tokens': 92, 'duration': 1.3517794609069824}
# {'path': 'executive-order-10182-providing-for-the-appointment-certain-persons-under-the-defense.json', 'input_tokens': 2249, 'output_tokens': 100, 'duration': 1.1529567241668701}
# {'path': 'executive-order-10183-making-certain-changes-internal-revenue-collection-districts-the.json', 'input_tokens': 1026, 'output_tokens': 100, 'duration': 1.1705522537231445}
# {'path': 'executive-order-10179-establishing-the-korean-service-medal.json', 'input_tokens': 1015, 'output_tokens': 173, 'duration': 2.0975546836853027}
# {'path': 'executive-order-10184-transferring-certain-land-comprising-portion-the-arecibo-coast-guard.json', 'input_tokens': 1203, 'output_tokens': 86, 'duration': 1.1330344676971436}
# {'path': 'executive-order-10185-amendment-executive-order-no-10166-october-4-1950.json', 'input_tokens': 1055, 'output_tokens': 99, 'duration': 1.2739648818969727}
# {'path': 'executive-order-10186-establishing-the-federal-civil-defense-administration-the-office-for.json', 'input_tokens': 1959, 'output_tokens': 102, 'duration': 1.1800711154937744}
# {'path': 'executive-order-10187-amendment-executive-order-no-10011-october-22-1948-amended.json', 'input_tokens': 1103, 'output_tokens': 107, 'duration': 1.2658679485321045}
# {'path': 'executive-order-10188-designating-the-honorable-luis-negron-fernandez-acting-judge-the.json', 'input_tokens': 967, 'output_tokens': 101, 'duration': 1.1758835315704346}
# {'path': 'executive-order-10190-prescribing-regulations-relating-new-trials-courts-martial-and-other.json', 'input_tokens': 2240, 'output_tokens': 118, 'duration': 1.3293330669403076}
# {'path': 'executive-order-10189-amendment-executive-order-no-4601-march-1-1927-prescribing.json', 'input_tokens': 1411, 'output_tokens': 133, 'duration': 1.4762487411499023}
# {'path': 'executive-order-10191-extension-trust-periods-indian-lands-expiring-during-the-calendar.json', 'input_tokens': 996, 'output_tokens': 96, 'duration': 1.3965349197387695}
