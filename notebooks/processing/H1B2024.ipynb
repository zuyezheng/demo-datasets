# %% [markdown]
# # H1B 2024
#
# https://github.com/BloombergGraphics/2024-h1b-immigration-data/blob/main/TRK_13139_FY2024_single_reg.zip

# %%
# %run ../../notebooks/Setup.ipynb

import pandas

# %%
# do some compression on the source csv
# df = pandas.read_csv(workspace_path.joinpath('data/raw/TRK_13139_FY2024_single_reg.csv'), low_memory=False)
# df.to_parquet(workspace_path.joinpath('data/raw/TRK_13139_FY2024_single_reg.parquet'), engine="pyarrow")

# load the compressed parquet file
df = pandas.read_parquet(workspace_path.joinpath('data/raw/TRK_13139_FY2024_single_reg.parquet'), engine="pyarrow")
df
# Out:
#            bcn country_of_birth country_of_nationality ben_date_of_birth  \
# 0       (b)(6)              IND                    IND            (b)(6)
# 1       (b)(6)              KOR                    KOR            (b)(6)
# 2       (b)(6)              IND                    IND            (b)(6)
# 3       (b)(6)              IND                    IND            (b)(6)
# 4       (b)(6)              GHA                    GHA            (b)(6)
# ...        ...              ...                    ...               ...
# 350098  (b)(6)              CHN                    CHN            (b)(6)
# 350099  (b)(6)              GBR                    IRL            (b)(6)
# 350100  (b)(6)              CHN                    CHN            (b)(6)
# 350101  (b)(6)              IND                    IND            (b)(6)
# 350102  (b)(6)              IND                    IND            (b)(6)
#
#        ben_year_of_birth  gender                       employer_name  \
# 0                   1994    male                 Mphasis Corporation
# 1                   1994    male  Tennessee Dental Professionals, PC
# 2                   1982    male                            KPMG LLP
# 3                   1995    male                 3D TECHNOLOGIES LLC
# 4                   1990    male                  LER TechForce, LLC
# ...                  ...     ...                                 ...
# 350098              1987    male                          Google LLC
# 350099              1989    male                     KLA Corporation
# 350100              2000  female               Deloitte & Touche LLP
# 350101              1987    male                    PRIAMBA SOFT LLC
# 350102              1984    male                   BrightFonts, Inc.
#
#              FEIN                       mail_addr           city  ... S1Q1B  \
# 0       954759720                  41 Madison Ave       New York  ...  None
# 1       200418100       1200 Network Centre Drive      Effingham  ...  None
# 2       135565207                   2323 Ross Ave         Dallas  ...  None
# 3       384053952              423 W Wheatland Rd    Duncanville  ...  None
# 4       352139176              1888 Poshard Drive       Columbus  ...  None
# ...           ...                             ...            ...  ...   ...
# 350098  770493581       1600 Amphitheatre Parkway  Mountain View  ...  None
# 350099  042564110            One Technology Drive       Milpitas  ...  None
# 350100  133891517              1700 Market Street   Philadelphia  ...  None
# 350101  462435519  517 Us Highway 1 S, Suite 1193         Iselin  ...  None
# 350102  472246802       222 West Las Colinas Blvd         Irving  ...  None
#
#        BEN_EDUCATION_CODE ED_LEVEL_DEFINITION BEN_PFIELD_OF_STUDY  \
# 0                    None                None                None
# 1                    None                None                None
# 2                    None                None                None
# 3                    None                None                None
# 4                    None                None                None
# ...                   ...                 ...                 ...
# 350098               None                None                None
# 350099               None                None                None
# 350100               None                None                None
# 350101               None                None                None
# 350102               None                None                None
#
#        BEN_COMP_PAID DOT_CODE NAICS_CODE  S3Q1  S4Q1 T_U_VAWA_FLAG
# 0               None     None       None  None  None          None
# 1               None     None       None  None  None          None
# 2               None     None       None  None  None          None
# 3               None     None       None  None  None          None
# 4               None     None       None  None  None          None
# ...              ...      ...        ...   ...   ...           ...
# 350098          None     None       None  None  None          None
# 350099          None     None       None  None  None          None
# 350100          None     None       None  None  None          None
# 350101          None     None       None  None  None          None
# 350102          None     None       None  None  None          None
#
# [350103 rows x 56 columns]

# %%
# Define the columns that need to be converted to numeric and datetime
numeric_cols = [
    'BEN_COMP_PAID', 'NUM_OF_EMP_IN_US', 'WAGE_AMT', 'NUMBER_OF_BENEFICIARIES', 'lottery_year', 'ben_year_of_birth'
]
date_cols = [
    'valid_to', 'valid_from', 'first_decision_date', 'rec_date', 'ben_date_of_birth'
]

# Convert numeric columns: invalid parsing will result in NaN
for col in numeric_cols:
    if col in df.columns:
        df[col] = pandas.to_numeric(df[col], errors='coerce')

# Convert date columns to timestamp[us]: invalid parsing will result in NaT
# The format is assumed to be like "9/30/2026"
for col in date_cols:
    if col in df.columns:
        df[col] = pandas.to_datetime(df[col], format='%m/%d/%Y', errors='coerce').dt.tz_localize(None)

# Convert all other columns to string
special_cols = set(numeric_cols + date_cols)
other_cols = [col for col in df.columns if col not in special_cols]
df[other_cols] = df[other_cols].astype(str)

# %%
# write to parquet
df.to_parquet(
    workspace_path.joinpath('data/processed/h1b2024.parquet'),
    engine="pyarrow",
    coerce_timestamps="us",
    allow_truncated_timestamps=True
)
