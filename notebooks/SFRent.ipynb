# %% [markdown]
# # SF Rent Board Housing Inventory

# %%
import pandas

# %%
inventory_df = pandas.read_csv('data/sf_rent/Rent_Board_Housing_Inventory_20250314.csv')

# show without truncating number of columns
pandas.set_option('display.max_columns', None)
inventory_df
# Out:
#                   unique_id block_num  unit_count  \
# 0      -3628485104392603866      3775          22
# 1      -2826846618703330734      3775          22
# 2      -8535828261092955964      3775          22
# 3      -9003118150577022274      3775          22
# 4       3838177617614172843      3775          22
# ...                     ...       ...         ...
# 186683 -7484992084690087964      3775          22
# 186684 -6165581344280503108      3775          22
# 186685 -6469473855511513476      1369          12
# 186686  -391686748792554513      3775          22
# 186687  -452610934157304139      3775          22
#
#                                      case_type_name  submission_year  \
# 0       Housing Inventory - Unit information (2024)             2024
# 1       Housing Inventory - Unit information (2024)             2024
# 2       Housing Inventory - Unit information (2024)             2024
# 3       Housing Inventory - Unit information (2024)             2024
# 4       Housing Inventory - Unit information (2024)             2024
# ...                                             ...              ...
# 186683  Housing Inventory - Unit information (2024)             2024
# 186684  Housing Inventory - Unit information (2024)             2024
# 186685  Housing Inventory - Unit information (2022)             2022
# 186686  Housing Inventory - Unit information (2024)             2024
# 186687  Housing Inventory - Unit information (2024)             2024
#
#                   block_address         occupancy_type  \
# 0       100 Block of SOUTH PARK  Occupied by non-owner
# 1       100 Block of SOUTH PARK  Occupied by non-owner
# 2       100 Block of SOUTH PARK  Occupied by non-owner
# 3       100 Block of SOUTH PARK  Occupied by non-owner
# 4       100 Block of SOUTH PARK  Occupied by non-owner
# ...                         ...                    ...
# 186683  100 Block of SOUTH PARK  Occupied by non-owner
# 186684  100 Block of SOUTH PARK                 Vacant
# 186685    100 Block of 09TH AVE                 Vacant
# 186686  100 Block of SOUTH PARK  Occupied by non-owner
# 186687  100 Block of SOUTH PARK                 Vacant
#
#        occupancy_or_vacancy_date occupancy_or_vacancy_date_year bedroom_count  \
# 0                     2022/01/31                           2022        Studio
# 1                     2022/02/08                           2022        Studio
# 2                     2022/01/31                           2022        Studio
# 3                     2022/01/31                           2022        Studio
# 4                     2023/05/03                           2023        Studio
# ...                          ...                            ...           ...
# 186683                2022/01/31                           2022        Studio
# 186684                       NaN                            NaN        Studio
# 186685                       NaN                            NaN   One-Bedroom
# 186686                2022/01/31                           2022        Studio
# 186687                       NaN                            NaN        Studio
#
#                                      bathroom_count square_footage  \
# 0       Shared bathroom facilities with other units    0-250 Sq.Ft
# 1       Shared bathroom facilities with other units    0-250 Sq.Ft
# 2       Shared bathroom facilities with other units    0-250 Sq.Ft
# 3       Shared bathroom facilities with other units    0-250 Sq.Ft
# 4       Shared bathroom facilities with other units    0-250 Sq.Ft
# ...                                             ...            ...
# 186683  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186684  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186685                                 One bathroom  501-750 Sq.Ft
# 186686  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186687  Shared bathroom facilities with other units    0-250 Sq.Ft
#
#        monthly_rent base_rent_includes_water base_rent_includes_natural_gas  \
# 0         $501-$750                        Y                              Y
# 1         $250-$500                        Y                              Y
# 2         $501-$750                        Y                              Y
# 3         $501-$750                        Y                              Y
# 4         $501-$750                        Y                              Y
# ...             ...                      ...                            ...
# 186683    $501-$750                        Y                              Y
# 186684          NaN                        N                              N
# 186685          NaN                        N                              N
# 186686   $751-$1000                        Y                              Y
# 186687          NaN                        N                              N
#
#        base_rent_includes_electricity base_rent_includes_refuse_recycling  \
# 0                                   Y                                   Y
# 1                                   Y                                   Y
# 2                                   Y                                   Y
# 3                                   Y                                   Y
# 4                                   Y                                   Y
# ...                               ...                                 ...
# 186683                              Y                                   Y
# 186684                              N                                   N
# 186685                              N                                   N
# 186686                              Y                                   Y
# 186687                              N                                   N
#
#        base_rent_includes_other_utilities past_occupancy vacancy_date  \
# 0                                     NaN             No          NaN
# 1                                     NaN             No          NaN
# 2                                     NaN             No          NaN
# 3                                     NaN             No          NaN
# 4                                     NaN            Yes          NaN
# ...                                   ...            ...          ...
# 186683                                NaN            Yes          NaN
# 186684                                NaN            Yes   2024/01/02
# 186685                                NaN            NaN   2022/06/21
# 186686                                NaN             No          NaN
# 186687                                NaN            Yes   2024/01/22
#
#        signature_date                  occupancy_or_vacancy_date_history  \
# 0          2024/02/29                                                NaN
# 1          2024/02/29                                                NaN
# 2          2024/02/29                                                NaN
# 3          2024/02/29                                                NaN
# 4          2024/02/29                                                NaN
# ...               ...                                                ...
# 186683     2024/02/29                                                NaN
# 186684     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
# 186685     2022/06/21                                                NaN
# 186686     2024/02/29                                                NaN
# 186687     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
#
#         year_property_built                                point  \
# 0                    1907.0  POINT (-122.394549329 37.781408195)
# 1                    1907.0  POINT (-122.394549329 37.781408195)
# 2                    1907.0  POINT (-122.394549329 37.781408195)
# 3                    1907.0  POINT (-122.394549329 37.781408195)
# 4                    1907.0  POINT (-122.394549329 37.781408195)
# ...                     ...                                  ...
# 186683               1907.0  POINT (-122.394549329 37.781408195)
# 186684               1907.0  POINT (-122.394549329 37.781408195)
# 186685               1924.0   POINT (-122.467900457 37.78559791)
# 186686               1907.0  POINT (-122.394549329 37.781408195)
# 186687               1907.0  POINT (-122.394549329 37.781408195)
#
#                  analysis_neighborhood  supervisor_district  \
# 0       Financial District/South Beach                  6.0
# 1       Financial District/South Beach                  6.0
# 2       Financial District/South Beach                  6.0
# 3       Financial District/South Beach                  6.0
# 4       Financial District/South Beach                  6.0
# ...                                ...                  ...
# 186683  Financial District/South Beach                  6.0
# 186684  Financial District/South Beach                  6.0
# 186685                  Inner Richmond                  1.0
# 186686  Financial District/South Beach                  6.0
# 186687  Financial District/South Beach                  6.0
#
#                     data_as_of          data_loaded_at
# 0       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 1       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 2       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 3       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 4       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# ...                        ...                     ...
# 186683  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186684  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186685  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186686  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186687  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
#
# [186688 rows x 28 columns]

# %%
"""
The point column are values such as:
POINT (-122.394549329 37.781408195)

Split these up to get the longitude and latitude values in 2 separate columns.
"""
inventory_df[['longitude', 'latitude']] = inventory_df['point']\
    .str.extract(r'POINT \((.*)\)')[0]\
    .str.split(' ', expand=True)

# convert the new columns to numeric
inventory_df['longitude'] = pandas.to_numeric(inventory_df['longitude'])
inventory_df['latitude'] = pandas.to_numeric(inventory_df['latitude'])

inventory_df
# Out:
#                   unique_id block_num  unit_count  \
# 0      -3628485104392603866      3775          22
# 1      -2826846618703330734      3775          22
# 2      -8535828261092955964      3775          22
# 3      -9003118150577022274      3775          22
# 4       3838177617614172843      3775          22
# ...                     ...       ...         ...
# 186683 -7484992084690087964      3775          22
# 186684 -6165581344280503108      3775          22
# 186685 -6469473855511513476      1369          12
# 186686  -391686748792554513      3775          22
# 186687  -452610934157304139      3775          22
#
#                                      case_type_name  submission_year  \
# 0       Housing Inventory - Unit information (2024)             2024
# 1       Housing Inventory - Unit information (2024)             2024
# 2       Housing Inventory - Unit information (2024)             2024
# 3       Housing Inventory - Unit information (2024)             2024
# 4       Housing Inventory - Unit information (2024)             2024
# ...                                             ...              ...
# 186683  Housing Inventory - Unit information (2024)             2024
# 186684  Housing Inventory - Unit information (2024)             2024
# 186685  Housing Inventory - Unit information (2022)             2022
# 186686  Housing Inventory - Unit information (2024)             2024
# 186687  Housing Inventory - Unit information (2024)             2024
#
#                   block_address         occupancy_type  \
# 0       100 Block of SOUTH PARK  Occupied by non-owner
# 1       100 Block of SOUTH PARK  Occupied by non-owner
# 2       100 Block of SOUTH PARK  Occupied by non-owner
# 3       100 Block of SOUTH PARK  Occupied by non-owner
# 4       100 Block of SOUTH PARK  Occupied by non-owner
# ...                         ...                    ...
# 186683  100 Block of SOUTH PARK  Occupied by non-owner
# 186684  100 Block of SOUTH PARK                 Vacant
# 186685    100 Block of 09TH AVE                 Vacant
# 186686  100 Block of SOUTH PARK  Occupied by non-owner
# 186687  100 Block of SOUTH PARK                 Vacant
#
#        occupancy_or_vacancy_date occupancy_or_vacancy_date_year bedroom_count  \
# 0                     2022/01/31                           2022        Studio
# 1                     2022/02/08                           2022        Studio
# 2                     2022/01/31                           2022        Studio
# 3                     2022/01/31                           2022        Studio
# 4                     2023/05/03                           2023        Studio
# ...                          ...                            ...           ...
# 186683                2022/01/31                           2022        Studio
# 186684                       NaN                            NaN        Studio
# 186685                       NaN                            NaN   One-Bedroom
# 186686                2022/01/31                           2022        Studio
# 186687                       NaN                            NaN        Studio
#
#                                      bathroom_count square_footage  \
# 0       Shared bathroom facilities with other units    0-250 Sq.Ft
# 1       Shared bathroom facilities with other units    0-250 Sq.Ft
# 2       Shared bathroom facilities with other units    0-250 Sq.Ft
# 3       Shared bathroom facilities with other units    0-250 Sq.Ft
# 4       Shared bathroom facilities with other units    0-250 Sq.Ft
# ...                                             ...            ...
# 186683  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186684  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186685                                 One bathroom  501-750 Sq.Ft
# 186686  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186687  Shared bathroom facilities with other units    0-250 Sq.Ft
#
#        monthly_rent base_rent_includes_water base_rent_includes_natural_gas  \
# 0         $501-$750                        Y                              Y
# 1         $250-$500                        Y                              Y
# 2         $501-$750                        Y                              Y
# 3         $501-$750                        Y                              Y
# 4         $501-$750                        Y                              Y
# ...             ...                      ...                            ...
# 186683    $501-$750                        Y                              Y
# 186684          NaN                        N                              N
# 186685          NaN                        N                              N
# 186686   $751-$1000                        Y                              Y
# 186687          NaN                        N                              N
#
#        base_rent_includes_electricity base_rent_includes_refuse_recycling  \
# 0                                   Y                                   Y
# 1                                   Y                                   Y
# 2                                   Y                                   Y
# 3                                   Y                                   Y
# 4                                   Y                                   Y
# ...                               ...                                 ...
# 186683                              Y                                   Y
# 186684                              N                                   N
# 186685                              N                                   N
# 186686                              Y                                   Y
# 186687                              N                                   N
#
#        base_rent_includes_other_utilities past_occupancy vacancy_date  \
# 0                                     NaN             No          NaN
# 1                                     NaN             No          NaN
# 2                                     NaN             No          NaN
# 3                                     NaN             No          NaN
# 4                                     NaN            Yes          NaN
# ...                                   ...            ...          ...
# 186683                                NaN            Yes          NaN
# 186684                                NaN            Yes   2024/01/02
# 186685                                NaN            NaN   2022/06/21
# 186686                                NaN             No          NaN
# 186687                                NaN            Yes   2024/01/22
#
#        signature_date                  occupancy_or_vacancy_date_history  \
# 0          2024/02/29                                                NaN
# 1          2024/02/29                                                NaN
# 2          2024/02/29                                                NaN
# 3          2024/02/29                                                NaN
# 4          2024/02/29                                                NaN
# ...               ...                                                ...
# 186683     2024/02/29                                                NaN
# 186684     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
# 186685     2022/06/21                                                NaN
# 186686     2024/02/29                                                NaN
# 186687     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
#
#         year_property_built                                point  \
# 0                    1907.0  POINT (-122.394549329 37.781408195)
# 1                    1907.0  POINT (-122.394549329 37.781408195)
# 2                    1907.0  POINT (-122.394549329 37.781408195)
# 3                    1907.0  POINT (-122.394549329 37.781408195)
# 4                    1907.0  POINT (-122.394549329 37.781408195)
# ...                     ...                                  ...
# 186683               1907.0  POINT (-122.394549329 37.781408195)
# 186684               1907.0  POINT (-122.394549329 37.781408195)
# 186685               1924.0   POINT (-122.467900457 37.78559791)
# 186686               1907.0  POINT (-122.394549329 37.781408195)
# 186687               1907.0  POINT (-122.394549329 37.781408195)
#
#                  analysis_neighborhood  supervisor_district  \
# 0       Financial District/South Beach                  6.0
# 1       Financial District/South Beach                  6.0
# 2       Financial District/South Beach                  6.0
# 3       Financial District/South Beach                  6.0
# 4       Financial District/South Beach                  6.0
# ...                                ...                  ...
# 186683  Financial District/South Beach                  6.0
# 186684  Financial District/South Beach                  6.0
# 186685                  Inner Richmond                  1.0
# 186686  Financial District/South Beach                  6.0
# 186687  Financial District/South Beach                  6.0
#
#                     data_as_of          data_loaded_at   longitude   latitude
# 0       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 1       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 2       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 3       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 4       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# ...                        ...                     ...         ...        ...
# 186683  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186684  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186685  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.467900  37.785598
# 186686  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186687  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
#
# [186688 rows x 30 columns]

# %%
# Clean up square footage and split into min and max
def extract_square_footage(text):
    if pandas.isna(text):
        return pandas.NA, pandas.NA
    
    # Remove common text patterns and convert to lowercase
    text = str(text).lower().replace('sq.ft', '').replace('sqft', '').replace('ft', '').replace('$', '').strip()
    
    # Handle ranges (e.g. "800-1000" or "800 - 1000")
    if '-' in text:
        parts = text.replace(' ', '').split('-')
        try:
            return float(parts[0]), float(parts[1])
        except:
            return pandas.NA, pandas.NA
    
    # Handle single values
    try:
        value = float(text.replace(',', ''))
        return value, value
    except:
        return pandas.NA, pandas.NA

# Apply the function and create new columns
inventory_df[['min_square_footage', 'max_square_footage']] = inventory_df['square_footage'].apply(
    lambda x: pandas.Series(extract_square_footage(x))
)

inventory_df
# Out:
#                   unique_id block_num  unit_count  \
# 0      -3628485104392603866      3775          22
# 1      -2826846618703330734      3775          22
# 2      -8535828261092955964      3775          22
# 3      -9003118150577022274      3775          22
# 4       3838177617614172843      3775          22
# ...                     ...       ...         ...
# 186683 -7484992084690087964      3775          22
# 186684 -6165581344280503108      3775          22
# 186685 -6469473855511513476      1369          12
# 186686  -391686748792554513      3775          22
# 186687  -452610934157304139      3775          22
#
#                                      case_type_name  submission_year  \
# 0       Housing Inventory - Unit information (2024)             2024
# 1       Housing Inventory - Unit information (2024)             2024
# 2       Housing Inventory - Unit information (2024)             2024
# 3       Housing Inventory - Unit information (2024)             2024
# 4       Housing Inventory - Unit information (2024)             2024
# ...                                             ...              ...
# 186683  Housing Inventory - Unit information (2024)             2024
# 186684  Housing Inventory - Unit information (2024)             2024
# 186685  Housing Inventory - Unit information (2022)             2022
# 186686  Housing Inventory - Unit information (2024)             2024
# 186687  Housing Inventory - Unit information (2024)             2024
#
#                   block_address         occupancy_type  \
# 0       100 Block of SOUTH PARK  Occupied by non-owner
# 1       100 Block of SOUTH PARK  Occupied by non-owner
# 2       100 Block of SOUTH PARK  Occupied by non-owner
# 3       100 Block of SOUTH PARK  Occupied by non-owner
# 4       100 Block of SOUTH PARK  Occupied by non-owner
# ...                         ...                    ...
# 186683  100 Block of SOUTH PARK  Occupied by non-owner
# 186684  100 Block of SOUTH PARK                 Vacant
# 186685    100 Block of 09TH AVE                 Vacant
# 186686  100 Block of SOUTH PARK  Occupied by non-owner
# 186687  100 Block of SOUTH PARK                 Vacant
#
#        occupancy_or_vacancy_date occupancy_or_vacancy_date_year bedroom_count  \
# 0                     2022/01/31                           2022        Studio
# 1                     2022/02/08                           2022        Studio
# 2                     2022/01/31                           2022        Studio
# 3                     2022/01/31                           2022        Studio
# 4                     2023/05/03                           2023        Studio
# ...                          ...                            ...           ...
# 186683                2022/01/31                           2022        Studio
# 186684                       NaN                            NaN        Studio
# 186685                       NaN                            NaN   One-Bedroom
# 186686                2022/01/31                           2022        Studio
# 186687                       NaN                            NaN        Studio
#
#                                      bathroom_count square_footage  \
# 0       Shared bathroom facilities with other units    0-250 Sq.Ft
# 1       Shared bathroom facilities with other units    0-250 Sq.Ft
# 2       Shared bathroom facilities with other units    0-250 Sq.Ft
# 3       Shared bathroom facilities with other units    0-250 Sq.Ft
# 4       Shared bathroom facilities with other units    0-250 Sq.Ft
# ...                                             ...            ...
# 186683  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186684  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186685                                 One bathroom  501-750 Sq.Ft
# 186686  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186687  Shared bathroom facilities with other units    0-250 Sq.Ft
#
#        monthly_rent base_rent_includes_water base_rent_includes_natural_gas  \
# 0         $501-$750                        Y                              Y
# 1         $250-$500                        Y                              Y
# 2         $501-$750                        Y                              Y
# 3         $501-$750                        Y                              Y
# 4         $501-$750                        Y                              Y
# ...             ...                      ...                            ...
# 186683    $501-$750                        Y                              Y
# 186684          NaN                        N                              N
# 186685          NaN                        N                              N
# 186686   $751-$1000                        Y                              Y
# 186687          NaN                        N                              N
#
#        base_rent_includes_electricity base_rent_includes_refuse_recycling  \
# 0                                   Y                                   Y
# 1                                   Y                                   Y
# 2                                   Y                                   Y
# 3                                   Y                                   Y
# 4                                   Y                                   Y
# ...                               ...                                 ...
# 186683                              Y                                   Y
# 186684                              N                                   N
# 186685                              N                                   N
# 186686                              Y                                   Y
# 186687                              N                                   N
#
#        base_rent_includes_other_utilities past_occupancy vacancy_date  \
# 0                                     NaN             No          NaN
# 1                                     NaN             No          NaN
# 2                                     NaN             No          NaN
# 3                                     NaN             No          NaN
# 4                                     NaN            Yes          NaN
# ...                                   ...            ...          ...
# 186683                                NaN            Yes          NaN
# 186684                                NaN            Yes   2024/01/02
# 186685                                NaN            NaN   2022/06/21
# 186686                                NaN             No          NaN
# 186687                                NaN            Yes   2024/01/22
#
#        signature_date                  occupancy_or_vacancy_date_history  \
# 0          2024/02/29                                                NaN
# 1          2024/02/29                                                NaN
# 2          2024/02/29                                                NaN
# 3          2024/02/29                                                NaN
# 4          2024/02/29                                                NaN
# ...               ...                                                ...
# 186683     2024/02/29                                                NaN
# 186684     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
# 186685     2022/06/21                                                NaN
# 186686     2024/02/29                                                NaN
# 186687     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
#
#         year_property_built                                point  \
# 0                    1907.0  POINT (-122.394549329 37.781408195)
# 1                    1907.0  POINT (-122.394549329 37.781408195)
# 2                    1907.0  POINT (-122.394549329 37.781408195)
# 3                    1907.0  POINT (-122.394549329 37.781408195)
# 4                    1907.0  POINT (-122.394549329 37.781408195)
# ...                     ...                                  ...
# 186683               1907.0  POINT (-122.394549329 37.781408195)
# 186684               1907.0  POINT (-122.394549329 37.781408195)
# 186685               1924.0   POINT (-122.467900457 37.78559791)
# 186686               1907.0  POINT (-122.394549329 37.781408195)
# 186687               1907.0  POINT (-122.394549329 37.781408195)
#
#                  analysis_neighborhood  supervisor_district  \
# 0       Financial District/South Beach                  6.0
# 1       Financial District/South Beach                  6.0
# 2       Financial District/South Beach                  6.0
# 3       Financial District/South Beach                  6.0
# 4       Financial District/South Beach                  6.0
# ...                                ...                  ...
# 186683  Financial District/South Beach                  6.0
# 186684  Financial District/South Beach                  6.0
# 186685                  Inner Richmond                  1.0
# 186686  Financial District/South Beach                  6.0
# 186687  Financial District/South Beach                  6.0
#
#                     data_as_of          data_loaded_at   longitude   latitude  \
# 0       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 1       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 2       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 3       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 4       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# ...                        ...                     ...         ...        ...
# 186683  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186684  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186685  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.467900  37.785598
# 186686  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186687  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
#
#        min_square_footage max_square_footage
# 0                     0.0              250.0
# 1                     0.0              250.0
# 2                     0.0              250.0
# 3                     0.0              250.0
# 4                     0.0              250.0
# ...                   ...                ...
# 186683                0.0              250.0
# 186684                0.0              250.0
# 186685              501.0              750.0
# 186686                0.0              250.0
# 186687                0.0              250.0
#
# [186688 rows x 32 columns]

# %%
def extract_montly_rent(text):
    if pandas.isna(text):
        return pandas.NA, pandas.NA
    
    # Remove common text patterns and convert to lowercase
    text = str(text).lower().replace('$', '').strip()
    
    # Handle ranges (e.g. "800-1000" or "800 - 1000")
    if '-' in text:
        parts = text.replace(' ', '').split('-')
        try:
            return float(parts[0]), float(parts[1])
        except:
            return pandas.NA, pandas.NA
    
    # Handle single values
    try:
        value = float(text.replace(',', ''))
        return value, value
    except:
        return pandas.NA, pandas.NA

# Apply the function and create new columns
inventory_df[['min_monthly_rent', 'max_monthly_rent']] = inventory_df['monthly_rent'].apply(
    lambda x: pandas.Series(extract_montly_rent(x))
)

inventory_df
# Out:
#                   unique_id block_num  unit_count  \
# 0      -3628485104392603866      3775          22
# 1      -2826846618703330734      3775          22
# 2      -8535828261092955964      3775          22
# 3      -9003118150577022274      3775          22
# 4       3838177617614172843      3775          22
# ...                     ...       ...         ...
# 186683 -7484992084690087964      3775          22
# 186684 -6165581344280503108      3775          22
# 186685 -6469473855511513476      1369          12
# 186686  -391686748792554513      3775          22
# 186687  -452610934157304139      3775          22
#
#                                      case_type_name  submission_year  \
# 0       Housing Inventory - Unit information (2024)             2024
# 1       Housing Inventory - Unit information (2024)             2024
# 2       Housing Inventory - Unit information (2024)             2024
# 3       Housing Inventory - Unit information (2024)             2024
# 4       Housing Inventory - Unit information (2024)             2024
# ...                                             ...              ...
# 186683  Housing Inventory - Unit information (2024)             2024
# 186684  Housing Inventory - Unit information (2024)             2024
# 186685  Housing Inventory - Unit information (2022)             2022
# 186686  Housing Inventory - Unit information (2024)             2024
# 186687  Housing Inventory - Unit information (2024)             2024
#
#                   block_address         occupancy_type  \
# 0       100 Block of SOUTH PARK  Occupied by non-owner
# 1       100 Block of SOUTH PARK  Occupied by non-owner
# 2       100 Block of SOUTH PARK  Occupied by non-owner
# 3       100 Block of SOUTH PARK  Occupied by non-owner
# 4       100 Block of SOUTH PARK  Occupied by non-owner
# ...                         ...                    ...
# 186683  100 Block of SOUTH PARK  Occupied by non-owner
# 186684  100 Block of SOUTH PARK                 Vacant
# 186685    100 Block of 09TH AVE                 Vacant
# 186686  100 Block of SOUTH PARK  Occupied by non-owner
# 186687  100 Block of SOUTH PARK                 Vacant
#
#        occupancy_or_vacancy_date occupancy_or_vacancy_date_year bedroom_count  \
# 0                     2022/01/31                           2022        Studio
# 1                     2022/02/08                           2022        Studio
# 2                     2022/01/31                           2022        Studio
# 3                     2022/01/31                           2022        Studio
# 4                     2023/05/03                           2023        Studio
# ...                          ...                            ...           ...
# 186683                2022/01/31                           2022        Studio
# 186684                       NaN                            NaN        Studio
# 186685                       NaN                            NaN   One-Bedroom
# 186686                2022/01/31                           2022        Studio
# 186687                       NaN                            NaN        Studio
#
#                                      bathroom_count square_footage  \
# 0       Shared bathroom facilities with other units    0-250 Sq.Ft
# 1       Shared bathroom facilities with other units    0-250 Sq.Ft
# 2       Shared bathroom facilities with other units    0-250 Sq.Ft
# 3       Shared bathroom facilities with other units    0-250 Sq.Ft
# 4       Shared bathroom facilities with other units    0-250 Sq.Ft
# ...                                             ...            ...
# 186683  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186684  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186685                                 One bathroom  501-750 Sq.Ft
# 186686  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186687  Shared bathroom facilities with other units    0-250 Sq.Ft
#
#        monthly_rent base_rent_includes_water base_rent_includes_natural_gas  \
# 0         $501-$750                        Y                              Y
# 1         $250-$500                        Y                              Y
# 2         $501-$750                        Y                              Y
# 3         $501-$750                        Y                              Y
# 4         $501-$750                        Y                              Y
# ...             ...                      ...                            ...
# 186683    $501-$750                        Y                              Y
# 186684          NaN                        N                              N
# 186685          NaN                        N                              N
# 186686   $751-$1000                        Y                              Y
# 186687          NaN                        N                              N
#
#        base_rent_includes_electricity base_rent_includes_refuse_recycling  \
# 0                                   Y                                   Y
# 1                                   Y                                   Y
# 2                                   Y                                   Y
# 3                                   Y                                   Y
# 4                                   Y                                   Y
# ...                               ...                                 ...
# 186683                              Y                                   Y
# 186684                              N                                   N
# 186685                              N                                   N
# 186686                              Y                                   Y
# 186687                              N                                   N
#
#        base_rent_includes_other_utilities past_occupancy vacancy_date  \
# 0                                     NaN             No          NaN
# 1                                     NaN             No          NaN
# 2                                     NaN             No          NaN
# 3                                     NaN             No          NaN
# 4                                     NaN            Yes          NaN
# ...                                   ...            ...          ...
# 186683                                NaN            Yes          NaN
# 186684                                NaN            Yes   2024/01/02
# 186685                                NaN            NaN   2022/06/21
# 186686                                NaN             No          NaN
# 186687                                NaN            Yes   2024/01/22
#
#        signature_date                  occupancy_or_vacancy_date_history  \
# 0          2024/02/29                                                NaN
# 1          2024/02/29                                                NaN
# 2          2024/02/29                                                NaN
# 3          2024/02/29                                                NaN
# 4          2024/02/29                                                NaN
# ...               ...                                                ...
# 186683     2024/02/29                                                NaN
# 186684     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
# 186685     2022/06/21                                                NaN
# 186686     2024/02/29                                                NaN
# 186687     2024/02/29  [\n  {\n    "date_range_type": "Occupied",\n  ...
#
#         year_property_built                                point  \
# 0                    1907.0  POINT (-122.394549329 37.781408195)
# 1                    1907.0  POINT (-122.394549329 37.781408195)
# 2                    1907.0  POINT (-122.394549329 37.781408195)
# 3                    1907.0  POINT (-122.394549329 37.781408195)
# 4                    1907.0  POINT (-122.394549329 37.781408195)
# ...                     ...                                  ...
# 186683               1907.0  POINT (-122.394549329 37.781408195)
# 186684               1907.0  POINT (-122.394549329 37.781408195)
# 186685               1924.0   POINT (-122.467900457 37.78559791)
# 186686               1907.0  POINT (-122.394549329 37.781408195)
# 186687               1907.0  POINT (-122.394549329 37.781408195)
#
#                  analysis_neighborhood  supervisor_district  \
# 0       Financial District/South Beach                  6.0
# 1       Financial District/South Beach                  6.0
# 2       Financial District/South Beach                  6.0
# 3       Financial District/South Beach                  6.0
# 4       Financial District/South Beach                  6.0
# ...                                ...                  ...
# 186683  Financial District/South Beach                  6.0
# 186684  Financial District/South Beach                  6.0
# 186685                  Inner Richmond                  1.0
# 186686  Financial District/South Beach                  6.0
# 186687  Financial District/South Beach                  6.0
#
#                     data_as_of          data_loaded_at   longitude   latitude  \
# 0       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 1       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 2       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 3       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 4       2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# ...                        ...                     ...         ...        ...
# 186683  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186684  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186685  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.467900  37.785598
# 186686  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
# 186687  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM -122.394549  37.781408
#
#        min_square_footage max_square_footage min_monthly_rent max_monthly_rent
# 0                     0.0              250.0            501.0            750.0
# 1                     0.0              250.0            250.0            500.0
# 2                     0.0              250.0            501.0            750.0
# 3                     0.0              250.0            501.0            750.0
# 4                     0.0              250.0            501.0            750.0
# ...                   ...                ...              ...              ...
# 186683                0.0              250.0            501.0            750.0
# 186684                0.0              250.0             <NA>             <NA>
# 186685              501.0              750.0             <NA>             <NA>
# 186686                0.0              250.0            751.0           1000.0
# 186687                0.0              250.0             <NA>             <NA>
#
# [186688 rows x 34 columns]

# %%
def extract_bedroom_count(text):
    if pandas.isna(text):
        return pandas.NA
    
    # cleanup
    text = str(text).lower().strip()

    # map numbers in words to numbers
    word_numbers = {
        'zero': 0,
        'one': 1,
        'two': 2,
        'three': 3,
        'four': 4,
        'five': 5
    }
    for word, number in word_numbers.items():
        text = text.replace(word, str(number))

    # special case for "5+"
    if text == '5+':
        return 6

    # extract only the contigous numbers e.g. "4-bedroom" -> 4, "0ah" -> 0
    number_str = ''
    for c in text:
        if c.isdigit():
            number_str += c
        else:
            break

    # cast to number
    try:
        num_bedrooms = int(number_str)
        if num_bedrooms > 5:
            return 0
        else:
            return num_bedrooms
    except:
        return 0

# %%
for bedrooms in inventory_df['bedroom_count'].unique():
    print(bedrooms, extract_bedroom_count(bedrooms))
# Out:
# Studio 0
# Two-Bedroom 2
# One-Bedroom 1
# Three-Bedroom 3
# nan <NA>
# Four-Bedroom 4
# 5+ 6
# 2 2
# 1 1
# 3 3
# Two Bedroom 2
# 0 0
# One Bedroom 1
# studio 0
# Studio (sm) 0
# Garage 0
# One-bedroom 1
# Two-bedroom 2
# 1 bedroom 1
# 2 bedroom 2
# 3 bedroom 3
# 2 bedroomq 2
# 1bedroom 1
# 3bedroom 3
# 2 bedriin 2
# $D$61 0
# 1 bed 1
# 2A 2
# 0A 0
# 1A 1
# 0AH 0
# Zero -(Studio) 0
# Zero-(Studio) 0
# Five-Bedroom 5
# Vacant 0
# 1br 1
# 2brd 2
# 2br 2

# %%
def extract_bathroom_count(text):
    if pandas.isna(text):
        return pandas.NA
    
    # cleanup
    text = str(text).lower().strip()

    # map numbers in words to numbers
    word_numbers = {
        'one and a half': 1.5,
        'two and a half': 2.5,
        'zero': 0,
        'one': 1,
        'two': 2,
        'three': 3
    }
    for word, number in word_numbers.items():
        text = text.replace(word, str(number))

    # extract the numbers
    number_str = ''
    for c in text:
        if c.isdigit() or c == '.':
            number_str += c
        else:
            break

    # cast to number
    try:
        return float(number_str)
    except:
        return 0

# %%
for bedrooms in inventory_df['bathroom_count'].unique():
    print(bedrooms, extract_bathroom_count(bedrooms))
# Out:
# Shared bathroom facilities with other units 0
# One bathroom 1.0
# Two bathrooms 2.0
# nan <NA>
# One and a half bathrooms 1.5
# Three bathrooms or more 3.0
# Two and a half bathrooms 2.5
# One-Bathroom 1.0
# 1.00 1.0
# 2.00 2.0
# 1 1.0
# 2 2.0
# 2.5 2.5
# One Bathroom 1.0
# Two Bathroom 2.0
# One and a Half Bathrooms 1.5
# shared bathroom facilities with other units 0
# 2 bathroom 2.0
# 1 bathroom 1.0
# 2 batroom 2.0
# 1 bedroom 1.0
# 2 bedroom 2.0
# 1bathroom 1.0
# 2  bathroom 2.0
# Two-Bathroom 2.0
# E3 0
# Two bathroom 2.0
# One and a half bathdrooms 1.5

# %%
inventory_df.rename(columns={
    'bedroom_count': 'bedrooms_raw',
    'bathroom_count': 'bathrooms_raw'
}, inplace=True)

inventory_df['bedrooms'] = inventory_df['bedrooms_raw'].apply(extract_bedroom_count)
inventory_df['bathrooms'] = inventory_df['bathrooms_raw'].apply(extract_bathroom_count)

# %%
inventory_df.drop(columns=[
    'occupancy_or_vacancy_date_history',
    'unique_id',
], inplace=True)

inventory_df.to_parquet('data/sf_rent/rent_board_inventory.parquet', index=False)

# %%
inventory_df
# Out:
#        block_num  unit_count                               case_type_name  \
# 0           3775          22  Housing Inventory - Unit information (2024)
# 1           3775          22  Housing Inventory - Unit information (2024)
# 2           3775          22  Housing Inventory - Unit information (2024)
# 3           3775          22  Housing Inventory - Unit information (2024)
# 4           3775          22  Housing Inventory - Unit information (2024)
# ...          ...         ...                                          ...
# 186683      3775          22  Housing Inventory - Unit information (2024)
# 186684      3775          22  Housing Inventory - Unit information (2024)
# 186685      1369          12  Housing Inventory - Unit information (2022)
# 186686      3775          22  Housing Inventory - Unit information (2024)
# 186687      3775          22  Housing Inventory - Unit information (2024)
#
#         submission_year            block_address         occupancy_type  \
# 0                  2024  100 Block of SOUTH PARK  Occupied by non-owner
# 1                  2024  100 Block of SOUTH PARK  Occupied by non-owner
# 2                  2024  100 Block of SOUTH PARK  Occupied by non-owner
# 3                  2024  100 Block of SOUTH PARK  Occupied by non-owner
# 4                  2024  100 Block of SOUTH PARK  Occupied by non-owner
# ...                 ...                      ...                    ...
# 186683             2024  100 Block of SOUTH PARK  Occupied by non-owner
# 186684             2024  100 Block of SOUTH PARK                 Vacant
# 186685             2022    100 Block of 09TH AVE                 Vacant
# 186686             2024  100 Block of SOUTH PARK  Occupied by non-owner
# 186687             2024  100 Block of SOUTH PARK                 Vacant
#
#        occupancy_or_vacancy_date occupancy_or_vacancy_date_year bedrooms_raw  \
# 0                     2022/01/31                           2022       Studio
# 1                     2022/02/08                           2022       Studio
# 2                     2022/01/31                           2022       Studio
# 3                     2022/01/31                           2022       Studio
# 4                     2023/05/03                           2023       Studio
# ...                          ...                            ...          ...
# 186683                2022/01/31                           2022       Studio
# 186684                       NaN                            NaN       Studio
# 186685                       NaN                            NaN  One-Bedroom
# 186686                2022/01/31                           2022       Studio
# 186687                       NaN                            NaN       Studio
#
#                                       bathrooms_raw square_footage  \
# 0       Shared bathroom facilities with other units    0-250 Sq.Ft
# 1       Shared bathroom facilities with other units    0-250 Sq.Ft
# 2       Shared bathroom facilities with other units    0-250 Sq.Ft
# 3       Shared bathroom facilities with other units    0-250 Sq.Ft
# 4       Shared bathroom facilities with other units    0-250 Sq.Ft
# ...                                             ...            ...
# 186683  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186684  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186685                                 One bathroom  501-750 Sq.Ft
# 186686  Shared bathroom facilities with other units    0-250 Sq.Ft
# 186687  Shared bathroom facilities with other units    0-250 Sq.Ft
#
#        monthly_rent base_rent_includes_water base_rent_includes_natural_gas  \
# 0         $501-$750                        Y                              Y
# 1         $250-$500                        Y                              Y
# 2         $501-$750                        Y                              Y
# 3         $501-$750                        Y                              Y
# 4         $501-$750                        Y                              Y
# ...             ...                      ...                            ...
# 186683    $501-$750                        Y                              Y
# 186684          NaN                        N                              N
# 186685          NaN                        N                              N
# 186686   $751-$1000                        Y                              Y
# 186687          NaN                        N                              N
#
#        base_rent_includes_electricity base_rent_includes_refuse_recycling  \
# 0                                   Y                                   Y
# 1                                   Y                                   Y
# 2                                   Y                                   Y
# 3                                   Y                                   Y
# 4                                   Y                                   Y
# ...                               ...                                 ...
# 186683                              Y                                   Y
# 186684                              N                                   N
# 186685                              N                                   N
# 186686                              Y                                   Y
# 186687                              N                                   N
#
#        past_occupancy vacancy_date signature_date  year_property_built  \
# 0                  No          NaN     2024/02/29               1907.0
# 1                  No          NaN     2024/02/29               1907.0
# 2                  No          NaN     2024/02/29               1907.0
# 3                  No          NaN     2024/02/29               1907.0
# 4                 Yes          NaN     2024/02/29               1907.0
# ...               ...          ...            ...                  ...
# 186683            Yes          NaN     2024/02/29               1907.0
# 186684            Yes   2024/01/02     2024/02/29               1907.0
# 186685            NaN   2022/06/21     2022/06/21               1924.0
# 186686             No          NaN     2024/02/29               1907.0
# 186687            Yes   2024/01/22     2024/02/29               1907.0
#
#                                       point           analysis_neighborhood  \
# 0       POINT (-122.394549329 37.781408195)  Financial District/South Beach
# 1       POINT (-122.394549329 37.781408195)  Financial District/South Beach
# 2       POINT (-122.394549329 37.781408195)  Financial District/South Beach
# 3       POINT (-122.394549329 37.781408195)  Financial District/South Beach
# 4       POINT (-122.394549329 37.781408195)  Financial District/South Beach
# ...                                     ...                             ...
# 186683  POINT (-122.394549329 37.781408195)  Financial District/South Beach
# 186684  POINT (-122.394549329 37.781408195)  Financial District/South Beach
# 186685   POINT (-122.467900457 37.78559791)                  Inner Richmond
# 186686  POINT (-122.394549329 37.781408195)  Financial District/South Beach
# 186687  POINT (-122.394549329 37.781408195)  Financial District/South Beach
#
#         supervisor_district              data_as_of          data_loaded_at  \
# 0                       6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 1                       6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 2                       6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 3                       6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 4                       6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# ...                     ...                     ...                     ...
# 186683                  6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186684                  6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186685                  1.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186686                  6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
# 186687                  6.0  2025/03/14 01:30:37 AM  2025/03/14 06:05:44 AM
#
#          longitude   latitude min_square_footage max_square_footage  \
# 0      -122.394549  37.781408                0.0              250.0
# 1      -122.394549  37.781408                0.0              250.0
# 2      -122.394549  37.781408                0.0              250.0
# 3      -122.394549  37.781408                0.0              250.0
# 4      -122.394549  37.781408                0.0              250.0
# ...            ...        ...                ...                ...
# 186683 -122.394549  37.781408                0.0              250.0
# 186684 -122.394549  37.781408                0.0              250.0
# 186685 -122.467900  37.785598              501.0              750.0
# 186686 -122.394549  37.781408                0.0              250.0
# 186687 -122.394549  37.781408                0.0              250.0
#
#        min_monthly_rent max_monthly_rent bedrooms bathrooms
# 0                 501.0            750.0        0         0
# 1                 250.0            500.0        0         0
# 2                 501.0            750.0        0         0
# 3                 501.0            750.0        0         0
# 4                 501.0            750.0        0         0
# ...                 ...              ...      ...       ...
# 186683            501.0            750.0        0         0
# 186684             <NA>             <NA>        0         0
# 186685             <NA>             <NA>        1       1.0
# 186686            751.0           1000.0        0         0
# 186687             <NA>             <NA>        0         0
#
# [186688 rows x 33 columns]

# %%
inventory_df.dtypes
# Out:
# block_num                               object
# unit_count                               int64
# case_type_name                          object
# submission_year                          int64
# block_address                           object
# occupancy_type                          object
# occupancy_or_vacancy_date               object
# occupancy_or_vacancy_date_year          object
# bedrooms_raw                            object
# bathrooms_raw                           object
# square_footage                          object
# monthly_rent                            object
# base_rent_includes_water                object
# base_rent_includes_natural_gas          object
# base_rent_includes_electricity          object
# base_rent_includes_refuse_recycling     object
# past_occupancy                          object
# vacancy_date                            object
# signature_date                          object
# year_property_built                    float64
# point                                   object
# analysis_neighborhood                   object
# supervisor_district                    float64
# data_as_of                              object
# data_loaded_at                          object
# longitude                              float64
# latitude                               float64
# min_square_footage                      object
# max_square_footage                      object
# min_monthly_rent                        object
# max_monthly_rent                        object
# bedrooms                                object
# bathrooms                               object
# dtype: object
